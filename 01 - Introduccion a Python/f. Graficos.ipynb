# %% [markdown]
# <div class="alert alert-block alert-info">
# <img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO">
# <br><font face = "Times New Roman" size = "6"><b><center>Maestría en Sistemas Computacionales</center></b></font>
# <br><font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
#
# <b><br><font face = "Times New Roman" size = "4"><center>Unidad 2: Conceptos Generales</center></font>
# <font face = "Times New Roman" size = "4"><center>Tema 2.2: Representación de Datos</center></font>
# <font face = "Times New Roman" size = "4"><center>Subtema f: Gráficos</center></font></b>
# </div>

# %% [markdown]
# ## GRÁFICOS
#
# Para el uso de gráficos en **Python** se empleará la librería **Matplotlib**.
#
# #### La Librería Matplotlib
# <br>
# <img src="./Imagenes/Matplotlib_logo.png" style="width:597px;height:120px;" class="center">
# <br>
#
# **Matplotlib** es una librería para la generación de gráficos a partir de datos contenidos en listas o arreglos en el lenguaje de programación **Python**.
#
# La documentación de **Matplotlib** se puede encontrar a través [de esta liga](https://matplotlib.org/users/index.html).
#
# Para importar la librería se empleará la función `from matplotlib import pyplot as plt`, a partir de ello se podrá hacer uso de los distintos métodos de `pyplot` invocándolo como `plt`.
#
# Como primer ejemplo se generará un gráfico de líneas empleando el método `.plot()` de la siguiente manera:

# %%
#Importación de Librerías
from matplotlib import pyplot as plt

#Definición de Valores
años = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
valores = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3, 17325.5] 

#Creación de una Gráfica de Líneas
plt.plot(años, valores, color='blue', marker='o', linestyle='solid') 

#Agregar Título y Etiquetas
plt.title("Valores Anuales")
plt.xlabel("Años")
plt.ylabel("Millones de Pesos") 
plt.show()

# %% [markdown]
# Ahora se generará un gráfico de barras empleando el método `.bar()` de la siguiente manera:

# %%
#Definición de Valores
pelicula = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"] 
num_oscar = [5, 11, 3, 8, 10]

#Creación de una Gráfica de Barras
xs = [i + 0.1 for i, _ in enumerate(pelicula)]
plt.bar(xs, num_oscar) 

#Agregar Título y Etiquetas
plt.xlabel("Películas")
plt.ylabel("Número de Premios de la Academia")
plt.title("Número de Premios por Película")

#Etiquetas en el Eje X
plt.xticks([i + 0.5 for i, _ in enumerate(pelicula)], pelicula) 
plt.show()

# %% [markdown]
# Para generar varios gráficos de líneas, se puede emplear el método `.plot()` de la siguiente manera:

# %%
#Definición de Valores
varianza = [1, 2, 4, 8, 16, 32, 64, 128, 256] 
error_cuad = [256, 128, 64, 32, 16, 8, 4, 2, 1]
error_total = [x + y for x, y in zip(varianza, error_cuad)] 
xs = [i for i, _ in enumerate(varianza)]

#Creación de la Gráfica de Líneas
plt.plot(xs, varianza, 'g-', label='varianza')          # línea verde sólida
plt.plot(xs, error_cuad, 'r-.', label='error cuad')     # línea roja discontínua
plt.plot(xs, error_total, 'b:', label='error total')    # línea azul

#Agregar Título y Etiquetas
#loc=9 significa "arriba al centro"
plt.legend(loc=9)
plt.xlabel("Complejidad del Modelo") 
plt.title("Niveles de Variación") 
plt.show()

# %% [markdown]
# Para generar un gráfico de dispersión se emplea el método `.scatter()` de la siguiente manera:

# %%
#Definición de Valores
amigos = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutos = [175, 170, 205, 120, 220, 130, 105, 145, 190]
etiquetas  = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

#Creación de la Gráfica de Dispersión
plt.scatter(amigos, minutos)

#Agregar Título y Etiquetas
for etiquetas, amigos_count, minutos_count in zip(etiquetas, amigos, minutos):
    plt.annotate(etiquetas,
    xy = (amigos_count, minutos_count),      # coloca la etiqueta en cada punto
    xytext=(5, -5),                          # pero con un pequeño desplazamiento
    textcoords='offset points')

plt.title("Minutos Diarios vs. Número de Amigos")
plt.xlabel("Número de amigos")
plt.ylabel("minutos diarios usados en el sitio") 
plt.show()

# %% [markdown]
# Finalmente, otro ejemplo para generar gráficos de dispersión empleando el método `.scatter()` de la siguiente manera:

# %%
#Definición de Valores
calif_prueba_1 = [ 99, 90, 85, 97, 80] 
calif_prueba_2 = [100, 85, 60, 90, 70]

#Creación de la Gráfica de Dispersión 1
plt.scatter(calif_prueba_1, calif_prueba_2) 
plt.title("Los Ejes no son Comparables") 
plt.xlabel("Calificaciones de la Prueba 1") 
plt.ylabel("Calificaciones de la Prueba 2")
plt.show()

# %%
#Creación de la Gráfica de Dispersión 2
plt.scatter(calif_prueba_1, calif_prueba_2) 
plt.title("Los Ejes son Comparables") 
plt.xlabel("Calificaciones de la Prueba 1") 
plt.ylabel("Calificaciones de la Prueba 2")
plt.axis("equal")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>.: Fin del Tema :.</b>
# </div>
