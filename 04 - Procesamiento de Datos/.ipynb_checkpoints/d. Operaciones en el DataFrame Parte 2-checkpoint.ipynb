# %% [markdown]
# <div class="alert alert-block alert-info">
# <img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO">
# <br><font face = "Times New Roman" size = "6"><b><center>Maestría en Sistemas Computacionales</center></b></font>
# <br><font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
#
# <b><br><font face = "Times New Roman" size = "4"><center>Unidad 4: Proceso de Obtención de Datos</center></font>
# <font face = "Times New Roman" size = "4"><center>Tema 4.1: Exploración, Integración y Limpieza de Datos</center></font>
# <font face = "Times New Roman" size = "4"><center>Subtema d: Operaciones en el DataFrame Parte 2</center></font></b>
# </div>

# %% [markdown]
# ## OPERACIONES EN EL DATAFRAME PARTE 2
#
# La clase **DataFrame** de **Pandas** contiene cientos de atributos y métodos que son de gran importancia para el proceso de análisis de datos. Estos pueden ser consultados en detalle por medio de [esta liga](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).
#
# Para ejemplificar algunos de ellos, se empleará una base de datos generada por ***Internet Movie DataBase (IMDB)***, la cual puede ser empleada de manera abierta para uso personal y/o no comercial. ***IMDB*** genera varias bases de datos las cuales están disponibles de manera gratuita, se actualizan diariamente y pueden ser descargadas a través de [esta liga](https://www.imdb.com/interfaces).
#
# Debido a que son bases de datos sumamente extensas (mayores a 500MB), se contará con una versión reducida de una de ellas para este ejercicio, la cual está almacenada en un archivo de nombre `IMBD_Data.csv` que contiene 12 columnas con 1000 entradas, y todos los datos contenidos en la misma están en el idioma *inglés*. Los encabezados de las columnas de información son:
#
# 1. **Rank**: Es un número consecutivo entre 1 y 1000.
# 2. **Title**: Es el título de la película.
# 3. **Genre**: Son los géneros a los cuales pertenece la película.
# 4. **Description**: Es un texto breve con una descripción de la película.
# 5. **Director**: Es el director de la película.
# 6. **Actors**: Son los actores principales de la película.
# 7. **Year**: Es el año de la película.
# 8. **Runtime (Minutes)**: Es el tiempo de duración de la película en minutos.
# 9. **Rating**: Es una valoración entre 0 y 10 de la película proporcionado por los críticos.
# 10. **Votes**: Es la cantidad de votos de las personas que recibió la película.
# 11. **Revenue (Millions)**: Es el ingreso recibido por la película en millones de dólares americanos.
# 12. **Metascore**: Es una valoración entre 0 y 100 basada en los votos de las personas que recibió la película.
#
# Para la lectura del archivo y la preparación de los datos, se realizarán las siguientes operaciones:
#
# 1. Importación de las librerías necesarias (**Pandas**, **Matplotlib** y **Seaborn**).
# 2. Lectura de los datos definiendo la columna `Title` como el **Indice** empleando el método `.read_csv()`.
# 3. Renombrado de los encabezados para eliminar los paréntesis empleando el método `.rename()`.
# 4. Renombrado de los encabezados a minúsculas empleando el método `.columns`.
# 5. Mostrar el **DataFrame** resultante empleando el método `.head()`.

# %%
#Importación de librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Lectura de los datos y asignación del nombre de las películas como el índice
movies_df = pd.read_csv("./Datos/IMDB_Data.csv", index_col = 'Title')

#Renombrado de encabezados de columnas para eliminar paréntesis
movies_df.rename(columns={
        'Runtime (Minutes)': 'Runtime', 
        'Revenue (Millions)': 'Revenue'
    }, inplace=True)

#Renombrado de encabezados de columnas a minúsculas
movies_df.columns = [col.lower() for col in movies_df]

#Impresión de los Resultados
print("El DataFrame es:")
movies_df.head()
# Out:
# El DataFrame es:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#                          year  runtime  rating   votes  revenue  metascore
# Title
# Guardians of the Galaxy  2014      121     8.1  757074   333.13       76.0
# Prometheus               2012      124     7.0  485820   126.46       65.0
# Split                    2016      117     7.3  157606   138.12       62.0
# Sing                     2016      108     7.2   60545   270.32       59.0
# Suicide Squad            2016      123     6.2  393727   325.02       40.0

# %% [markdown]
# ### Imputación de Datos
#
# Como se había visto, existen dos columnas en el **DataFrame** que contienen ***valores nulos*** (`revenue` y `metascore`).
#
# Primeramente se hará la **Imputación** de los ***valores nulos*** en la columna `revenue` reemplazándolos con el valor de media de la columna (como se había revisado previamente), esto es:

# %%
#Determinación del Valor de la Media de la Columna
revenue_mean = movies_df['revenue'].mean()

#Asignación de Valores de Media a los Valores Nulos
movies_df['revenue'].fillna(revenue_mean, inplace = True)

#Impresión del Conteo de Valores Nulos
print("Cantidad de Valores Nulos en \"revenue\" =", movies_df['revenue'].isnull().sum())
# Out:
# Cantidad de Valores Nulos en "revenue" = 0

# %% [markdown]
# ### Relaciones entre las Variables
#
# Empleando el método de **Correlación** definido por `.corr()`, se pueden general las relaciones entre las variables continuas, mostrando una **Matriz de Correlación** la cual es de gran uso para ciertos tipos de análisis.
#
# Para realizar el gráfico de la **Matriz de Correlación** empleando la librería **Seaborn** se utilizará el método `.heatmap(a,b,c)` de la librería **Seaborn**, cuyos argumentos corresponden a:
#
# * Argumento a: Es el valor de la **Matriz de Correlación** extraída del **DataFrame**.
# * Argumento b: Corresponde a `annot = True` que indica que se mostrarán las anotaciones relevantes como los nombres de las variables y los valores de la **Matriz de Correlación**.
# * Argumento c: Corresponde a `cmap = 'cool'` e indica el mapa de color a ser utilizado. Los mapas de color disponibles en **Seaborn** son los empleados por **Matplotlib** y pueden ser consultados [en esta liga](https://matplotlib.org/3.3.2/tutorials/colors/colormaps.html).

# %%
#Generación de la Matriz de Correlación
mat_corr = sns.heatmap(movies_df.corr(), annot = True, cmap = 'cool')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# ### Selección y Extracción de Datos desde el DataFrame
#
# #### Por Columna
#
# Previamente se revisó la manera de extraer una columna a través del uso sencillo de corchetes:

# %%
#Extracción de una Columna como una Serie
genre_col = movies_df['genre']

#Impresión de los Resultados
print("La columna es del tipo:", type(genre_col))
print("El tamaño de la columna es:", genre_col.shape)
genre_col
# Out:
# La columna es del tipo: <class 'pandas.core.series.Series'>
# El tamaño de la columna es: (1000,)
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
#                                      ...
# Secret in Their Eyes            Crime,Drama,Mystery
# Hostel: Part II                              Horror
# Step Up 2: The Streets          Drama,Music,Romance
# Search Party                       Adventure,Comedy
# Nine Lives                    Comedy,Family,Fantasy
# Name: genre, Length: 1000, dtype: object

# %% [markdown]
# Esta operación una **Serie** que ha sido extraída del **DataFrame**. Es importante recordar que esta **Serie** tiene asociado el **Indice** aunque no se considere parte de la misma.
#
# Sin embargo, para extraer una columna como un **DataFrame** se necesita pasar una lista de nombres de columnas, en este caso y considerando que solo es una columna:

# %%
#Extracción de una Columna como un DataFrame
genre_col = movies_df[['genre']]

#Impresión de los Resultados
print("La columna es del tipo:", type(genre_col))
print("El tamaño de la columna es:", genre_col.shape)
genre_col
# Out:
# La columna es del tipo: <class 'pandas.core.frame.DataFrame'>
# El tamaño de la columna es: (1000, 1)
#                                             genre
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %% [markdown]
# De esta manera, es posible extraer toda una serie de columnas del **DataFrame** original en un nuevo **DataFrame**. Por ejemplo, para extraer las columnas `genre` y `rating` se realiza lo siguiente:

# %%
#Extracción de una Columna como un DataFrame
subset = movies_df[['genre', 'rating']]

#Impresión de los Resultados
print("El tamaño del DataFrame es:", subset.shape)
subset.head()
# Out:
# El tamaño del DataFrame es: (1000, 2)
#                                             genre  rating
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi     8.1
# Prometheus               Adventure,Mystery,Sci-Fi     7.0
# Split                             Horror,Thriller     7.3
# Sing                      Animation,Comedy,Family     7.2
# Suicide Squad            Action,Adventure,Fantasy     6.2

# %% [markdown]
# #### Por Reglón
#
# Para extraer renglones del **DataFrame**, existen dos métodos en **Pandas** que permiten realizarlo, estos son:
#
# * Método `.loc[]` - Localiza un renglón por nombre en el **Indice**.
# * Método `.iloc[]` - Localiza un renglón por su **Indice** numérico.
#
# Debido a que la columna `Title` se está empleando como el **Indice** del **DataFrame**, para emplear `.loc` se proporciona el nombre de una película.
#
# La documentación del método `.loc[]` de **Pandas** puede ser consultada [en esta liga](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html).
#
# ***Nota:*** El nombre que se utilice debe coincidir con el contenido en el **Indice** del **DataFrame**.

# %%
#Extracción de un Renglón del DataFrame
peli_ren = movies_df.loc['Prometheus']

#Impresión de los Resultados
print("La información de la película es:")
peli_ren
# Out:
# La información de la película es:
# rank                                                           2
# genre                                   Adventure,Mystery,Sci-Fi
# description    Following clues to the origin of mankind, a te...
# director                                            Ridley Scott
# actors         Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                        2012
# runtime                                                      124
# rating                                                         7
# votes                                                     485820
# revenue                                                   126.46
# metascore                                                     65
# Name: Prometheus, dtype: object

# %% [markdown]
# Por otro lado, con el método `.iloc[]` se proporciona el valor numérico del **Indice** al cual pertenece la película *Prometheus*, en este caso es el segundo renglón (posición número 1).
#
# La documentación del método `.iloc[]` de **Pandas** puede ser consultada [en esta liga](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html).

# %%
#Extracción de un Renglón del DataFrame
peli_ren = movies_df.iloc[1]

#Impresión de los Resultados
print("La información de la película es:")
peli_ren
# Out:
# La información de la película es:
# rank                                                           2
# genre                                   Adventure,Mystery,Sci-Fi
# description    Following clues to the origin of mankind, a te...
# director                                            Ridley Scott
# actors         Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                        2012
# runtime                                                      124
# rating                                                         7
# votes                                                     485820
# revenue                                                   126.46
# metascore                                                     65
# Name: Prometheus, dtype: object

# %% [markdown]
# Los métodos `.loc[]` y `.iloc[]` pueden ser utilizados de manera similar a una **Lista** de **Python**.
#
# De esa manera, para poder realizar la selección de múltiples renglones, en **Python** se empleaban corchetes de esta manera: `lista[1:4]`. Es similar su uso a través de la libería **Pandas**.
#
# Por ejemplo, para crear un nuevo **DataFrame** que contenga los renglones que van desde la película *Prometheus* hasta la película *Sing* se realiza lo siguiente empleando el método `.loc[]`:

# %%
#Extracción de Renglones del DataFrame con loc
movie_subset = movies_df.loc['Prometheus':'Sing']

#Impresión de los Resultados
print("Los datos del nuevo DataFrame son:")
movie_subset
# Out:
# Los datos del nuevo DataFrame son:
#             rank                     genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        actors  year  runtime  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016      117
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
#             rating   votes  revenue  metascore
# Title
# Prometheus     7.0  485820   126.46       65.0
# Split          7.3  157606   138.12       62.0
# Sing           7.2   60545   270.32       59.0

# %% [markdown]
# De manera similar, para crear un nuevo **DataFrame** que contenga los renglones que van desde la película *Prometheus* (segundo renglón) hasta la película *Sing* (cuarto renglón) se realiza lo siguiente empleando el método `.iloc[]`:

# %%
#Extracción de Renglones del DataFrame con iloc
movie_subset = movies_df.iloc[1:4]

#Impresión de los Resultados
print("Los datos del nuevo DataFrame son:")
movie_subset
# Out:
# Los datos del nuevo DataFrame son:
#             rank                     genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        actors  year  runtime  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016      117
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
#             rating   votes  revenue  metascore
# Title
# Prometheus     7.0  485820   126.46       65.0
# Split          7.3  157606   138.12       62.0
# Sing           7.2   60545   270.32       59.0

# %% [markdown]
# ***Nota:*** Una distinción importante entre el uso de los métodos `.loc[]` y `.iloc[]` para realizar la selección de varios renglones, es que `.loc[]` incluye la película *Sing* en el resultado, pero con el uso de `.iloc[]` la película en el índice número 4 (*Suicide Squad*) no se incluye, tal y como funciona con las listas de **Python**.

# %% [markdown]
# ### Selecciones Condicionales
# Se han revisado las maneras de extraer columnas y renglones a partir del **DataFrame**, sin embargo en muchas ocasiones es necesario aplicar ciertas reglas para realizar selecciones condicionales.
#
# Por ejemplo, si se requiere filtrar el **DataFrame** para mostrar solamente las películas que han sido dirigidas por cierto Director, o las películas que tienen un *rating* superior o igual a *8.0*.
#
# Para ello, tomaremos una columna del **DataFrame** y se le aplicará una condición Booleana. Por ejemplo, para obtener las películas que han sido dirigidas por *Ridley Scott*, se empleará la columna `director` como base y se extraerán los elementos. Primeramente se revisará que la columna contenga a este director:

# %%
#Revisión de la Condición
condicion = (movies_df['director'] == "Ridley Scott")

#Impresión de los Resultados
print("El resultado de aplicar la condición es:\n", condicion.head(10))
print("\nLa cantidad de películas dirigidas por Ridley Scott contenidas en el DataFrame son: ", condicion.sum())
# Out:
# El resultado de aplicar la condición es:
#  Title
# Guardians of the Galaxy    False
# Prometheus                  True
# Split                      False
# Sing                       False
# Suicide Squad              False
# The Great Wall             False
# La La Land                 False
# Mindhorn                   False
# The Lost City of Z         False
# Passengers                 False
# Name: director, dtype: bool
#
# La cantidad de películas dirigidas por Ridley Scott contenidas en el DataFrame son:  8

# %% [markdown]
# De manera similar al método `.isnull()`, tenemos una **Serie** de valores Booleanos (`True` y `False`) en base a la condición indicada, es decir: `True` para las películas dirigidas por *Ridley Scott*, y `False` para las que no fueron dirigidas por él.
#
# El siguiente paso es filtrar las películas que no han sido dirigidas por *Ridley Scott*, es decir, eliminar las películas que tienen valores `False`.
#
# Para regresar los renglones donde la condición es `True`, es necesario pasar la operación que se describe a continuacón hacia el **DataFrame**.
#
# ***Nota:*** Debido a que no se incluye el argumento `inplace = True`, el **DataFrame** original no se verá afectado, por ello se incluye el método `.head()` para poder mostrar el resultado de la operación de filtrado.

# %%
#Filtrado de Elementos con Condicionante
movies_df[movies_df['director'] == "Ridley Scott"].head(10)
# Out:
#                         rank                     genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# The Counselor           A lawyer finds himself in over his head when h...
# A Good Year             A British investment broker inherits his uncle...
# Body of Lies            A CIA agent on the ground in Jordan hunts down...
#
#                             director  \
# Title
# Prometheus              Ridley Scott
# The Martian             Ridley Scott
# Robin Hood              Ridley Scott
# American Gangster       Ridley Scott
# Exodus: Gods and Kings  Ridley Scott
# The Counselor           Ridley Scott
# A Good Year             Ridley Scott
# Body of Lies            Ridley Scott
#
#                                                                    actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
# The Counselor           Michael Fassbender, Penélope Cruz, Cameron Dia...
# A Good Year             Russell Crowe, Abbie Cornish, Albert Finney, M...
# Body of Lies            Leonardo DiCaprio, Russell Crowe, Mark Strong,...
#
#                         year  runtime  rating   votes  revenue  metascore
# Title
# Prometheus              2012      124     7.0  485820   126.46       65.0
# The Martian             2015      144     8.0  556097   228.43       80.0
# Robin Hood              2010      140     6.7  221117   105.22       53.0
# American Gangster       2007      157     7.8  337835   130.13       76.0
# Exodus: Gods and Kings  2014      150     6.0  137299    65.01       52.0
# The Counselor           2013      117     5.3   84927    16.97       48.0
# A Good Year             2006      117     6.9   74674     7.46       47.0
# Body of Lies            2008      128     7.1  182305    39.38       57.0

# %% [markdown]
# Una manera de acostumbrarse a la interpretación de esta condición es leerla como:
# ```python
# movies_df[movies_df['director'] == "Ridley Scott"]
# ```
#
# > Toma el **DataFrame movies_df**, considerando solo los renglones donde el `director` en **movies_df** es igual a *Ridley Scott*.
#
# Ahora, para el caso de valores numéricos cuando se realiza un filtrado del **DataFrame** a través de la columna `rating` solicitando que solo se muestren las películas que tengan un valor mayor o igual a *8.6*:

# %%
#Filtrado de Elementos con Condicionante
movies_df[movies_df['rating'] >= 8.6].head(10)
# Out:
#                   rank                    genre  \
# Title
# Interstellar        37   Adventure,Drama,Sci-Fi
# The Dark Knight     55       Action,Crime,Drama
# Inception           81  Action,Adventure,Sci-Fi
# Kimi no na wa       97  Animation,Drama,Fantasy
# Dangal             118   Action,Biography,Drama
# The Intouchables   250   Biography,Comedy,Drama
#
#                                                         description  \
# Title
# Interstellar      A team of explorers travel through a wormhole ...
# The Dark Knight   When the menace known as the Joker wreaks havo...
# Inception         A thief, who steals corporate secrets through ...
# Kimi no na wa     Two strangers find themselves linked in a biza...
# Dangal            Former wrestler Mahavir Singh Phogat and his t...
# The Intouchables  After he becomes a quadriplegic from a paragli...
#
#                            director  \
# Title
# Interstellar      Christopher Nolan
# The Dark Knight   Christopher Nolan
# Inception         Christopher Nolan
# Kimi no na wa        Makoto Shinkai
# Dangal                Nitesh Tiwari
# The Intouchables    Olivier Nakache
#
#                                                              actors  year  \
# Title
# Interstellar      Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# The Dark Knight   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# Inception         Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# Kimi no na wa     Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016
# Dangal            Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
# The Intouchables  François Cluzet, Omar Sy, Anne Le Ny, Audrey F...  2011
#
#                   runtime  rating    votes  revenue  metascore
# Title
# Interstellar          169     8.6  1047747   187.99       74.0
# The Dark Knight       152     9.0  1791916   533.32       82.0
# Inception             148     8.8  1583625   292.57       74.0
# Kimi no na wa         106     8.6    34110     4.68       79.0
# Dangal                161     8.8    48969    11.15        NaN
# The Intouchables      112     8.6   557965    13.18       57.0

# %% [markdown]
# Es posible realizar mejoras en los condicionales a través del uso de operadores lógicos:
#
# * El símbolo `|` para el operador lógico ***o (or)***.
# * El símbolo `&` para el operador lógico ***y (and)***.
#
# Por ejemplo, para filtrar el **DataFrame** mostrando solo las películas que hayan sido dirigidas por *Christopher Nolan* ***o*** *Ridley Scott*:

# %%
#Filtrado de Elementos con Condicionante
movies_df[(movies_df['director'] == "Christopher Nolan") | (movies_df['director'] == "Ridley Scott")].head(10)
# Out:
#                         rank                     genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
#
#                                                               description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# Interstellar            A team of explorers travel through a wormhole ...
# The Dark Knight         When the menace known as the Joker wreaks havo...
# The Prestige            Two stage magicians engage in competitive one-...
# Inception               A thief, who steals corporate secrets through ...
# The Martian             An astronaut becomes stranded on Mars after hi...
# The Dark Knight Rises   Eight years after the Joker's reign of anarchy...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
#
#                                  director  \
# Title
# Prometheus                   Ridley Scott
# Interstellar            Christopher Nolan
# The Dark Knight         Christopher Nolan
# The Prestige            Christopher Nolan
# Inception               Christopher Nolan
# The Martian                  Ridley Scott
# The Dark Knight Rises   Christopher Nolan
# Robin Hood                   Ridley Scott
# American Gangster            Ridley Scott
# Exodus: Gods and Kings       Ridley Scott
#
#                                                                    actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Interstellar            Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight         Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige            Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception               Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# The Dark Knight Rises   Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
#
#                         year  runtime  rating    votes  revenue  metascore
# Title
# Prometheus              2012      124     7.0   485820   126.46       65.0
# Interstellar            2014      169     8.6  1047747   187.99       74.0
# The Dark Knight         2008      152     9.0  1791916   533.32       82.0
# The Prestige            2006      130     8.5   913152    53.08       66.0
# Inception               2010      148     8.8  1583625   292.57       74.0
# The Martian             2015      144     8.0   556097   228.43       80.0
# The Dark Knight Rises   2012      164     8.5  1222645   448.13       78.0
# Robin Hood              2010      140     6.7   221117   105.22       53.0
# American Gangster       2007      157     7.8   337835   130.13       76.0
# Exodus: Gods and Kings  2014      150     6.0   137299    65.01       52.0

# %% [markdown]
# Es importante que cada una de las condicionantes que se están evaluando vayan agrupadas en paréntesis para que **Python** comprenda adecuadamente la manera de realizar el proceso.
#
# Empleando el método `.isin()`, se puede realizar de manera más concisa, por ejemplo, para verificar que en la columna `director` del **DataFrame** se encuentra *Christopher Nolan* ***o*** *Ridley Scott*, la forma de usar el método es:

# %%
#Filtrado de Elementos con Condicionante
movies_df[movies_df['director'].isin(['Christopher Nolan', 'Ridley Scott'])].head(10)
# Out:
#                         rank                     genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
#
#                                                               description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# Interstellar            A team of explorers travel through a wormhole ...
# The Dark Knight         When the menace known as the Joker wreaks havo...
# The Prestige            Two stage magicians engage in competitive one-...
# Inception               A thief, who steals corporate secrets through ...
# The Martian             An astronaut becomes stranded on Mars after hi...
# The Dark Knight Rises   Eight years after the Joker's reign of anarchy...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
#
#                                  director  \
# Title
# Prometheus                   Ridley Scott
# Interstellar            Christopher Nolan
# The Dark Knight         Christopher Nolan
# The Prestige            Christopher Nolan
# Inception               Christopher Nolan
# The Martian                  Ridley Scott
# The Dark Knight Rises   Christopher Nolan
# Robin Hood                   Ridley Scott
# American Gangster            Ridley Scott
# Exodus: Gods and Kings       Ridley Scott
#
#                                                                    actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Interstellar            Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight         Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige            Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception               Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# The Dark Knight Rises   Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
#
#                         year  runtime  rating    votes  revenue  metascore
# Title
# Prometheus              2012      124     7.0   485820   126.46       65.0
# Interstellar            2014      169     8.6  1047747   187.99       74.0
# The Dark Knight         2008      152     9.0  1791916   533.32       82.0
# The Prestige            2006      130     8.5   913152    53.08       66.0
# Inception               2010      148     8.8  1583625   292.57       74.0
# The Martian             2015      144     8.0   556097   228.43       80.0
# The Dark Knight Rises   2012      164     8.5  1222645   448.13       78.0
# Robin Hood              2010      140     6.7   221117   105.22       53.0
# American Gangster       2007      157     7.8   337835   130.13       76.0
# Exodus: Gods and Kings  2014      150     6.0   137299    65.01       52.0

# %% [markdown]
# Ahora se aplicará un filtro más complicado, se pretende obtener todas las películas que:
#
# 1. Hayan salido entre *2005* y *2010* (columna `year`).
# 2. Tengan una valoración superior a *8.0* (coluna `rating`).
# 3. Que estén por debajo del *25%* de ingreso en taquilla (columna `revenue`).
#
# Todo ello se puede obtener de la siguiente manera:

# %%
#Filtrado de Elementos con Condicionante
movies_df[
    ((movies_df['year'] >= 2005) & (movies_df['year'] <= 2010))
    & (movies_df['rating'] > 8.0)
    & (movies_df['revenue'] < movies_df['revenue'].quantile(0.25))
].head(10)
# Out:
#                      rank               genre  \
# Title
# 3 Idiots              431        Comedy,Drama
# The Lives of Others   477      Drama,Thriller
# Incendies             714   Drama,Mystery,War
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Incendies            Twins journey to the Middle East to discover t...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
# Incendies                            Denis Villeneuve
# Taare Zameen Par                           Aamir Khan
#
#                                                                 actors  year  \
# Title
# 3 Idiots               Aamir Khan, Madhavan, Mona Singh, Sharman Joshi  2009
# The Lives of Others  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# Incendies            Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim...  2010
# Taare Zameen Par     Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
#
#                      runtime  rating   votes  revenue  metascore
# Title
# 3 Idiots                 170     8.4  238789     6.52       67.0
# The Lives of Others      137     8.5  278103    11.28       89.0
# Incendies                131     8.2   92863     6.86       80.0
# Taare Zameen Par         165     8.5  102697     1.20       42.0

# %% [markdown]
# Para acceder los valores por debajo del *25%* del valor máximo de ingreso en taquilla en la columna `revenue`, se empleó el método `.quantile()` con el valor flotante de 0.25. De esto resultan solo 4 películas de este filtrado que cumplen con las 3 condiciones establecidas.

# %% [markdown]
# ### Aplicación de Funciones
# Es posible realizar iteraciones sobre un **DataFrame** o una **Serie** de manera similar a una **Lista**, pero realizar este proceso puede ser muy lento, especialmente cuando la serie de datos es muy extensa.
#
# Una alternativa eficiente para realizarlo es a través del método `.apply()` para aplicar una **Función** al **DataFrame**. Por ejemplo, es posible emplear una **Función** para convertir las películas que tengan un valor de *8.0 o mayor* en la columna `rating` a una cadena que tenga el valor *good* y el resto tengan el valor *bad*, y asignar estos nuevos valores a una columna adicional.
#
# La documentación del método `.apply()` de **Pandas** puede ser consultada [en esta liga](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html).
#
# El primer paso es crear la **Función** que, cuando reciba un valor desde la columna `rating` determine si la película es *good* o si es *bad*:

# %%
#Definición de la Función
def funcion_category(x):
    if x >= 8.0:
        return "good"
    else:
        return "bad"

# %% [markdown]
# Como siguiente paso, se deberán de enviar los valores de toda la columna `rating` a través de esta **Función**, los valores que se obtengan se agregarán a una nueva columna de nombre `category`.
#
# Para ello se emplea el método `.apply()` de la siguiente manera:

# %%
#Impresión de los Resultados
print("El tamaño del DataFrame es:", movies_df.shape)

#Aplicación de la Función al DataFrame
movies_df['category'] = movies_df['rating'].apply(funcion_category)

#Impresión de los Resultados
print("El tamaño del nuevo DataFrame es:", movies_df.shape)
movies_df.head(10)
# Out:
# El tamaño del DataFrame es: (1000, 11)
# El tamaño del nuevo DataFrame es: (1000, 12)
#                          rank                       genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# The Great Wall           European mercenaries searching for black powde...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Mindhorn                 A has-been actor best known for playing the ti...
# The Lost City of Z       A true-life drama, centering on British explor...
# Passengers               A spacecraft traveling to a distant colony pla...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# The Great Wall                    Yimou Zhang
# La La Land                    Damien Chazelle
# Mindhorn                           Sean Foley
# The Lost City of Z                 James Gray
# Passengers                      Morten Tyldum
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# The Great Wall               Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Mindhorn                 Essie Davis, Andrea Riseborough, Julian Barrat...
# The Lost City of Z       Charlie Hunnam, Robert Pattinson, Sienna Mille...
# Passengers               Jennifer Lawrence, Chris Pratt, Michael Sheen,...
#
#                          year  runtime  rating   votes     revenue  metascore  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074  333.130000       76.0
# Prometheus               2012      124     7.0  485820  126.460000       65.0
# Split                    2016      117     7.3  157606  138.120000       62.0
# Sing                     2016      108     7.2   60545  270.320000       59.0
# Suicide Squad            2016      123     6.2  393727  325.020000       40.0
# The Great Wall           2016      103     6.1   56036   45.130000       42.0
# La La Land               2016      128     8.3  258682  151.060000       93.0
# Mindhorn                 2016       89     6.4    2490   82.956376       71.0
# The Lost City of Z       2016      141     7.1    7188    8.010000       78.0
# Passengers               2016      116     7.0  192177  100.010000       41.0
#
#                         category
# Title
# Guardians of the Galaxy     good
# Prometheus                   bad
# Split                        bad
# Sing                         bad
# Suicide Squad                bad
# The Great Wall               bad
# La La Land                  good
# Mindhorn                     bad
# The Lost City of Z           bad
# Passengers                   bad

# %% [markdown]
# También es posible realizarlo a través de una **Función Lambda**, la cual regresa el mismo resultado que la función `funcion_category`.
#
# Para ello se emplea nuevamente el método `.apply()` de la siguiente manera:

# %%
#Aplicación de la Función al DataFrame
movies_df['category'] = movies_df['rating'].apply(lambda x: 'good' if x >= 8.0 else 'bad')

#Impresión de los Resultados
print("El tamaño del nuevo DataFrame es:", movies_df.shape)
movies_df.head(10)
# Out:
# El tamaño del nuevo DataFrame es: (1000, 12)
#                          rank                       genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# The Great Wall           European mercenaries searching for black powde...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Mindhorn                 A has-been actor best known for playing the ti...
# The Lost City of Z       A true-life drama, centering on British explor...
# Passengers               A spacecraft traveling to a distant colony pla...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# The Great Wall                    Yimou Zhang
# La La Land                    Damien Chazelle
# Mindhorn                           Sean Foley
# The Lost City of Z                 James Gray
# Passengers                      Morten Tyldum
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# The Great Wall               Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Mindhorn                 Essie Davis, Andrea Riseborough, Julian Barrat...
# The Lost City of Z       Charlie Hunnam, Robert Pattinson, Sienna Mille...
# Passengers               Jennifer Lawrence, Chris Pratt, Michael Sheen,...
#
#                          year  runtime  rating   votes     revenue  metascore  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074  333.130000       76.0
# Prometheus               2012      124     7.0  485820  126.460000       65.0
# Split                    2016      117     7.3  157606  138.120000       62.0
# Sing                     2016      108     7.2   60545  270.320000       59.0
# Suicide Squad            2016      123     6.2  393727  325.020000       40.0
# The Great Wall           2016      103     6.1   56036   45.130000       42.0
# La La Land               2016      128     8.3  258682  151.060000       93.0
# Mindhorn                 2016       89     6.4    2490   82.956376       71.0
# The Lost City of Z       2016      141     7.1    7188    8.010000       78.0
# Passengers               2016      116     7.0  192177  100.010000       41.0
#
#                         category
# Title
# Guardians of the Galaxy     good
# Prometheus                   bad
# Split                        bad
# Sing                         bad
# Suicide Squad                bad
# The Great Wall               bad
# La La Land                  good
# Mindhorn                     bad
# The Lost City of Z           bad
# Passengers                   bad

# %% [markdown]
# A manera de conclusión, el uso del método `.apply()` es mucho más sencillo y rápido que realizar un proceso de iteración manual para cada renglón, esto debido a que **Pandas** emplea vectorización.
#
# > Vectorización: Es un estilo de programación donde las operaciones son aplicadas a todo el arreglo en lugar de aplicarlo a un cierto número de elementos individuales — [Wikipedia](https://en.wikipedia.org/wiki/Vectorization).

# %% [markdown]
# ### Normalización de Columnas
#
# Es posible realizar la normalización de los valores contenidos en una columna del **DataFrame** o en una **Serie**, a través del método `.apply()` para aplicar una función de normalización al grupo de datos.
#
# Como ejemplo, se normalizará la columna `revenue` del **DataFrame** a través de una **Función Lambda**, para ello será necesario seguir los siguientes pasos:
#
# 1. Determinar el valor mínimo de la columna `revenue` empleando el método `.min()`.
# 2. Determinar el valor máximo de la columna `revenue` empleando el método `.max()`.
# 3. Se agregará una nueva columna para almacenar los datos normalizados llamada `revenue_nor`.
# 4. Se guardará el **DataFrame** completo en un archivo llamado `IMDB_Data_Clean.csv`.
#
# Este proceso puede ser de gran utilidad para identificar la distribución de las ganancias en una escala definida (0 a 1), lo cual puede traducirse fácilmente en un porcentaje.

# %%
#Determinación del Valor Mínimo
min = movies_df['revenue'].min()

#Determinación del Valor Máximo
max = movies_df['revenue'].max()

#Aplicación de la Función al DataFrame
movies_df['revenue_nor'] = movies_df['revenue'].apply(lambda x: (x - min) / (max - min))

#Guardado del Archivo en formato CSV
movies_df.to_csv("./Datos/IMDB_Data_Clean.csv")

#Valores mínimo y máximo antes y después de la normalización
min_n = movies_df['revenue_nor'].min()
max_n = movies_df['revenue_nor'].max()

#Impresión de los Resultados
print("Antes de la Normalización: Valor Mínimo =", min, ", Valor Máximo = ",max)
print("Después de la Normalización: Valor Mínimo =", min_n, ", Valor Máximo = ",max_n)
print("El tamaño del nuevo DataFrame es:", movies_df.shape)
movies_df.head(10)
# Out:
# Antes de la Normalización: Valor Mínimo = 0.0 , Valor Máximo =  936.63
# Después de la Normalización: Valor Mínimo = 0.0 , Valor Máximo =  1.0
# El tamaño del nuevo DataFrame es: (1000, 13)
#                          rank                       genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# The Great Wall           European mercenaries searching for black powde...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Mindhorn                 A has-been actor best known for playing the ti...
# The Lost City of Z       A true-life drama, centering on British explor...
# Passengers               A spacecraft traveling to a distant colony pla...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# The Great Wall                    Yimou Zhang
# La La Land                    Damien Chazelle
# Mindhorn                           Sean Foley
# The Lost City of Z                 James Gray
# Passengers                      Morten Tyldum
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# The Great Wall               Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Mindhorn                 Essie Davis, Andrea Riseborough, Julian Barrat...
# The Lost City of Z       Charlie Hunnam, Robert Pattinson, Sienna Mille...
# Passengers               Jennifer Lawrence, Chris Pratt, Michael Sheen,...
#
#                          year  runtime  rating   votes     revenue  metascore  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074  333.130000       76.0
# Prometheus               2012      124     7.0  485820  126.460000       65.0
# Split                    2016      117     7.3  157606  138.120000       62.0
# Sing                     2016      108     7.2   60545  270.320000       59.0
# Suicide Squad            2016      123     6.2  393727  325.020000       40.0
# The Great Wall           2016      103     6.1   56036   45.130000       42.0
# La La Land               2016      128     8.3  258682  151.060000       93.0
# Mindhorn                 2016       89     6.4    2490   82.956376       71.0
# The Lost City of Z       2016      141     7.1    7188    8.010000       78.0
# Passengers               2016      116     7.0  192177  100.010000       41.0
#
#                         category  revenue_nor
# Title
# Guardians of the Galaxy     good     0.355669
# Prometheus                   bad     0.135016
# Split                        bad     0.147465
# Sing                         bad     0.288609
# Suicide Squad                bad     0.347010
# The Great Wall               bad     0.048183
# La La Land                  good     0.161280
# Mindhorn                     bad     0.088569
# The Lost City of Z           bad     0.008552
# Passengers                   bad     0.106776

# %% [markdown]
# ### Gráficos Informativos
#
# Como ya se ha comentado, una de las enormes ventajas de **Pandas** es su integración con la librería **Matplotlib**, de esa manera es posibe realizar gráficos de manera directa desde **Series** y **DataFrames**.
#
# Para definir algunas características de los gráficos como el tamaño de la fuente o el tamaño del gráfico, se puede emplear el método `.rcParams.update()` de **Matplotlib** de la siguiente manera:
# ```python
# plt.rcParams.update({'font.size': 12, 'figure.figsize': (6, 4)})
# ```
# Existen parámetros adicionales que pueden ser actualizados por medio del método `.rcParams.update()` de **Matplotlib**, los cuales pueden ser consultados [en esta liga](https://matplotlib.org/3.3.2/api/matplotlib_configuration_api.html).

# %%
#Definición de los parámetros de los gráficos
plt.rcParams.update({'font.size': 12, 'figure.figsize': (6, 4)})

# %% [markdown]
# ***Nota:*** La recomendación de los tipos de gráficos depende de las variables:
# * Para variables categóricas es mejor el uso de *Bar Charts* y *Boxplots*.
# * Para variables continuas es mejor el uso de *Histograms*, *Scatterplots*, *Line graphs* y *Boxplots*.
#
# Como primer ejercicio se graficará la relación entre las columnas `rating` y `revenue`. Para ello hay que emplear el método `.plot()` en el **DataFrame** `movies_df` con información adicional para construir el gráfico:

# %%
#Gráfica de Dispersión de Datos
movies_df.plot(kind='scatter', x='rating', y='revenue', title='Revenue (millions) vs Rating');

# %% [markdown]
# **Nota Relevante:**
# ¿Por qué aparece un `;` al final de la instrucción? No es un error, es solo para ocultar la salida `<matplotlib.axes._subplots.AxesSubplot at 0x26613b5cc18>` que se genera en **Jupyter** al momento de realizar el gráfico.
#
# Para realizar el Histograma de una columna del **DataFrame**, siplemente se grafica sobre esa columna. Por ejemplo, para la columna `rating` será:

# %%
#Gráfica de Histograma de Datos
movies_df['rating'].plot(kind='hist', title='Rating');

# %% [markdown]
# Como se había revisado previamente, el método `.describe()` en un **DataFrame** proporciona el resumen de la distribución de variables en el mismo. Existe una manera de representar gráficamente el rango de los cuartiles al interior de una columna, esto se realiza a través de un gráfico llamado *Boxplot*. Para ello, primeramente se revisará el contenido de la columna `rating`:

# %%
#Valores Estadísticos de la Columna
movies_df['rating'].describe()
# Out:
# count    1000.000000
# mean        6.723200
# std         0.945429
# min         1.900000
# 25%         6.200000
# 50%         6.800000
# 75%         7.400000
# max         9.000000
# Name: rating, dtype: float64

# %% [markdown]
# A través de un *Boxplot* podemos visualizar esta información. El máximo interés de un *Boxplot* es visualizar la distribución de una variable numérica de la manera más simplificada posible. Sólo utiliza los valores de los cuartiles, los extremos (el mínimo y el máximo) y valores *raros o outliers*.
#
# Primero ordena la variable y después la caracteriza según la posición de los cuartiles y los valores extremos.
#
# La gracia del *Boxplot* es visualizar una variable numérica de diferentes grupos o categorías, facilitando las cosas cuando se debe realizar la comparativa de varios grupos. Se visualiza de manera simlar a:
#
# <br>
# <img src="./Imagenes/Boxplot.png" style="width:444px;height:320px;" class="center">
# <br>
#
# Para este caso, el *Boxplot* de la columna `rating` se obtendrá de la siguiente manera:

# %%
#Gráfica de Boxplot de Datos
movies_df['rating'].plot(kind="box");

# %% [markdown]
# Adicional a ello, se puede realizar considerando las categorías de los valores contenidos en las columnas.
#
# Por ejemplo, el *Boxplot* de la columna `rating` pero categorizada por medio de los valores de la columna `category` quedará de la siguiente manera:

# %%
movies_df.boxplot(column='revenue', by='category');

# %% [markdown]
# Existen muchos tipos de gráficos adicionales, los cuales pueden revisarse a través de la documentación del método `.plot()` de **Pandas** a través de [esta liga](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>.: Fin del Subtema :.</b>
# </div>
#
# ***Liga de aceso al siguiente Subtema:***
# <br>[e. Combinación de DataFrames](e.%20Combinacion%20de%20DataFrames.ipynb)
