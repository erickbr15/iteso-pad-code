# %% [markdown]
# <div class="alert alert-block alert-info">
# <img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO">
# <br><font face = "Times New Roman" size = "6"><b><center>Maestría en Sistemas Computacionales</center></b></font>
# <br><font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
#
# <b><br><font face = "Times New Roman" size = "4"><center>Unidad 5: Proceso de Selección de Métodos</center></font>
# <font face = "Times New Roman" size = "4"><center>Tema 5.1: Procesamiento de Lenguaje Natural</center></font>
# <font face = "Times New Roman" size = "4"><center>Subtema b: Conteo de Palabras por Enunciado</center></font></b>
# </div>

# %% [markdown]
# ## CONTEO DE PALABRAS POR ENUNCIADO
#
# Para este ejemplo, se empleará el **Corpus** llamado `Inaugural`, el cual contiene los discursos de toma de protesta de los Presidentes de los Estados Unidos de América del año 1789 al año 2017.
#
# Se descargará adicionalmente un recurso llamado `punkt`, el cual es un ***tokenizador*** que divide un texto en una lista de enunciados (sentencias) a través de un algoritmo no supervisado para construir un modelo para palabras abreviadas, colocaciones y palabras que comienzan enunciados.

# %%
#Importación de la librería NLTK
import nltk

#Descarga del corpus Inaugural
nltk.download('inaugural')

#Descarga del recurso 'punkt'
nltk.download('punkt')

#Revisar los identificadores del corpus por medio de método .fileids()
nltk.corpus.inaugural.fileids()
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\erick\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\inaugural.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\erick\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1965-Johnson.txt',
#  '1969-Nixon.txt',
#  '1973-Nixon.txt',
#  '1977-Carter.txt',
#  '1981-Reagan.txt',
#  '1985-Reagan.txt',
#  '1989-Bush.txt',
#  '1993-Clinton.txt',
#  '1997-Clinton.txt',
#  '2001-Bush.txt',
#  '2005-Bush.txt',
#  '2009-Obama.txt',
#  '2013-Obama.txt',
#  '2017-Trump.txt',
#  '2021-Biden.txt']

# %% [markdown]
# Se muestra a continuación una manera de calcular la cantidad de elementos en cada uno de dichos discursos empleando un ciclo `for` que contenga las siguientes acciones:
#
# 1. Empleando el método `.corpus.inaugural.words()` para leer el archivo.
# 2. Empleando el método `len()` para realizar el conteo de elementos en el documento.
# 3. Imprimiendo los resultados.
#
# Esto es:

# %%
#Cantidad de palabras en cada documento
for discurso in nltk.corpus.inaugural.fileids():
    palabras_total = len(nltk.corpus.inaugural.words(discurso))
    print("La cantidad de elementos en el discurso", discurso, "es de:", palabras_total, "elementos.")
# Out:
# La cantidad de elementos en el discurso 1789-Washington.txt es de: 1538 elementos.
# La cantidad de elementos en el discurso 1793-Washington.txt es de: 147 elementos.
# La cantidad de elementos en el discurso 1797-Adams.txt es de: 2585 elementos.
# La cantidad de elementos en el discurso 1801-Jefferson.txt es de: 1935 elementos.
# La cantidad de elementos en el discurso 1805-Jefferson.txt es de: 2384 elementos.
# La cantidad de elementos en el discurso 1809-Madison.txt es de: 1265 elementos.
# La cantidad de elementos en el discurso 1813-Madison.txt es de: 1304 elementos.
# La cantidad de elementos en el discurso 1817-Monroe.txt es de: 3693 elementos.
# La cantidad de elementos en el discurso 1821-Monroe.txt es de: 4909 elementos.
# La cantidad de elementos en el discurso 1825-Adams.txt es de: 3150 elementos.
# La cantidad de elementos en el discurso 1829-Jackson.txt es de: 1208 elementos.
# La cantidad de elementos en el discurso 1833-Jackson.txt es de: 1267 elementos.
# La cantidad de elementos en el discurso 1837-VanBuren.txt es de: 4171 elementos.
# La cantidad de elementos en el discurso 1841-Harrison.txt es de: 9165 elementos.
# La cantidad de elementos en el discurso 1845-Polk.txt es de: 5196 elementos.
# La cantidad de elementos en el discurso 1849-Taylor.txt es de: 1182 elementos.
# La cantidad de elementos en el discurso 1853-Pierce.txt es de: 3657 elementos.
# La cantidad de elementos en el discurso 1857-Buchanan.txt es de: 3098 elementos.
# La cantidad de elementos en el discurso 1861-Lincoln.txt es de: 4005 elementos.
# La cantidad de elementos en el discurso 1865-Lincoln.txt es de: 785 elementos.
# La cantidad de elementos en el discurso 1869-Grant.txt es de: 1239 elementos.
# La cantidad de elementos en el discurso 1873-Grant.txt es de: 1478 elementos.
# La cantidad de elementos en el discurso 1877-Hayes.txt es de: 2724 elementos.
# La cantidad de elementos en el discurso 1881-Garfield.txt es de: 3239 elementos.
# La cantidad de elementos en el discurso 1885-Cleveland.txt es de: 1828 elementos.
# La cantidad de elementos en el discurso 1889-Harrison.txt es de: 4750 elementos.
# La cantidad de elementos en el discurso 1893-Cleveland.txt es de: 2153 elementos.
# La cantidad de elementos en el discurso 1897-McKinley.txt es de: 4371 elementos.
# La cantidad de elementos en el discurso 1901-McKinley.txt es de: 2450 elementos.
# La cantidad de elementos en el discurso 1905-Roosevelt.txt es de: 1091 elementos.
# La cantidad de elementos en el discurso 1909-Taft.txt es de: 5846 elementos.
# La cantidad de elementos en el discurso 1913-Wilson.txt es de: 1905 elementos.
# La cantidad de elementos en el discurso 1917-Wilson.txt es de: 1656 elementos.
# La cantidad de elementos en el discurso 1921-Harding.txt es de: 3756 elementos.
# La cantidad de elementos en el discurso 1925-Coolidge.txt es de: 4442 elementos.
# La cantidad de elementos en el discurso 1929-Hoover.txt es de: 3890 elementos.
# La cantidad de elementos en el discurso 1933-Roosevelt.txt es de: 2063 elementos.
# La cantidad de elementos en el discurso 1937-Roosevelt.txt es de: 2019 elementos.
# La cantidad de elementos en el discurso 1941-Roosevelt.txt es de: 1536 elementos.
# La cantidad de elementos en el discurso 1945-Roosevelt.txt es de: 637 elementos.
# La cantidad de elementos en el discurso 1949-Truman.txt es de: 2528 elementos.
# La cantidad de elementos en el discurso 1953-Eisenhower.txt es de: 2775 elementos.
# La cantidad de elementos en el discurso 1957-Eisenhower.txt es de: 1917 elementos.
# La cantidad de elementos en el discurso 1961-Kennedy.txt es de: 1546 elementos.
# La cantidad de elementos en el discurso 1965-Johnson.txt es de: 1715 elementos.
# La cantidad de elementos en el discurso 1969-Nixon.txt es de: 2425 elementos.
# La cantidad de elementos en el discurso 1973-Nixon.txt es de: 2028 elementos.
# La cantidad de elementos en el discurso 1977-Carter.txt es de: 1380 elementos.
# La cantidad de elementos en el discurso 1981-Reagan.txt es de: 2801 elementos.
# La cantidad de elementos en el discurso 1985-Reagan.txt es de: 2946 elementos.
# La cantidad de elementos en el discurso 1989-Bush.txt es de: 2713 elementos.
# La cantidad de elementos en el discurso 1993-Clinton.txt es de: 1855 elementos.
# La cantidad de elementos en el discurso 1997-Clinton.txt es de: 2462 elementos.
# La cantidad de elementos en el discurso 2001-Bush.txt es de: 1825 elementos.
# La cantidad de elementos en el discurso 2005-Bush.txt es de: 2376 elementos.
# La cantidad de elementos en el discurso 2009-Obama.txt es de: 2726 elementos.
# La cantidad de elementos en el discurso 2013-Obama.txt es de: 2369 elementos.
# La cantidad de elementos en el discurso 2017-Trump.txt es de: 1693 elementos.

# %% [markdown]
# Con esto, es posible crear una lista que contenga la cantidad de elementos junto con su respectivo documento. Para ello se empeará el método `.extend()` de **Python** de la siguiente manera:

# %%
#Creación de una lista con la cantidad de elementos y el documento asociado
lista_lon = []   
for discurso in nltk.corpus.inaugural.fileids():
    lista_lon.extend([(len(nltk.corpus.inaugural.words(discurso)), discurso)])

#Impresión de los Resultados
print("La cantidad de documentos en la lista es:", len(lista_lon))
print("\nLa lista es:\n", lista_lon)
# Out:
# La cantidad de documentos en la lista es: 58
#
# La lista es:
#  [(1538, '1789-Washington.txt'), (147, '1793-Washington.txt'), (2585, '1797-Adams.txt'), (1935, '1801-Jefferson.txt'), (2384, '1805-Jefferson.txt'), (1265, '1809-Madison.txt'), (1304, '1813-Madison.txt'), (3693, '1817-Monroe.txt'), (4909, '1821-Monroe.txt'), (3150, '1825-Adams.txt'), (1208, '1829-Jackson.txt'), (1267, '1833-Jackson.txt'), (4171, '1837-VanBuren.txt'), (9165, '1841-Harrison.txt'), (5196, '1845-Polk.txt'), (1182, '1849-Taylor.txt'), (3657, '1853-Pierce.txt'), (3098, '1857-Buchanan.txt'), (4005, '1861-Lincoln.txt'), (785, '1865-Lincoln.txt'), (1239, '1869-Grant.txt'), (1478, '1873-Grant.txt'), (2724, '1877-Hayes.txt'), (3239, '1881-Garfield.txt'), (1828, '1885-Cleveland.txt'), (4750, '1889-Harrison.txt'), (2153, '1893-Cleveland.txt'), (4371, '1897-McKinley.txt'), (2450, '1901-McKinley.txt'), (1091, '1905-Roosevelt.txt'), (5846, '1909-Taft.txt'), (1905, '1913-Wilson.txt'), (1656, '1917-Wilson.txt'), (3756, '1921-Harding.txt'), (4442, '1925-Coolidge.txt'), (3890, '1929-Hoover.txt'), (2063, '1933-Roosevelt.txt'), (2019, '1937-Roosevelt.txt'), (1536, '1941-Roosevelt.txt'), (637, '1945-Roosevelt.txt'), (2528, '1949-Truman.txt'), (2775, '1953-Eisenhower.txt'), (1917, '1957-Eisenhower.txt'), (1546, '1961-Kennedy.txt'), (1715, '1965-Johnson.txt'), (2425, '1969-Nixon.txt'), (2028, '1973-Nixon.txt'), (1380, '1977-Carter.txt'), (2801, '1981-Reagan.txt'), (2946, '1985-Reagan.txt'), (2713, '1989-Bush.txt'), (1855, '1993-Clinton.txt'), (2462, '1997-Clinton.txt'), (1825, '2001-Bush.txt'), (2376, '2005-Bush.txt'), (2726, '2009-Obama.txt'), (2369, '2013-Obama.txt'), (1693, '2017-Trump.txt')]

# %% [markdown]
# A partir de esta lista, se pueden emplear diversos métodos de utilidad. Por ejemplo, para determinar el discurso más extenso se usa el método `.max()`:

# %%
#Determinación del discurso más extenso
print("El discurso más extenso es: ", max(lista_lon))
# Out:
# El discurso más extenso es:  (9165, '1841-Harrison.txt')

# %% [markdown]
# De manera similar, para determinar el discurso más corto se usa el método `.min()`:

# %%
#Determinación del discurso más corto
print("El discurso más corto es: ", min(lista_lon))
# Out:
# El discurso más corto es:  (147, '1793-Washington.txt')

# %% [markdown]
# Ahora se realizará un conteo de la cantidad total de palabras (método `.len()`) en cada discurso (de manera similar a lo realizado previamente) por medio del método `.words()` aplicado al **Corpus**.
#
# Adicionalmente, se contará la cantidad de enunciados (método `.len()`) contenidos en cada discurso empleando el recurso `punkt` y por medio del método `.sents()` aplicado al **Corpus**.
#
# Finalmente, se calcula la relación entre palabras totales por enunciados totales, esto para cada uno de los documentos empleando un ciclo `for`:

# %%
#Determinación de la relación de palabras por enunciado
for discurso in nltk.corpus.inaugural.fileids():
    pala_tot = len(nltk.corpus.inaugural.words(discurso))
    enun_tot = len(nltk.corpus.inaugural.sents(discurso))
    print("La relación de palabras por enunciado es de: %.2f"% (pala_tot/enun_tot), "para el discurso:", discurso)
# Out:
# La relación de palabras por enunciado es de: 64.08 para el discurso: 1789-Washington.txt
# La relación de palabras por enunciado es de: 36.75 para el discurso: 1793-Washington.txt
# La relación de palabras por enunciado es de: 69.86 para el discurso: 1797-Adams.txt
# La relación de palabras por enunciado es de: 46.07 para el discurso: 1801-Jefferson.txt
# La relación de palabras por enunciado es de: 52.98 para el discurso: 1805-Jefferson.txt
# La relación de palabras por enunciado es de: 60.24 para el discurso: 1809-Madison.txt
# La relación de palabras por enunciado es de: 39.52 para el discurso: 1813-Madison.txt
# La relación de palabras por enunciado es de: 30.27 para el discurso: 1817-Monroe.txt
# La relación de palabras por enunciado es de: 38.05 para el discurso: 1821-Monroe.txt
# La relación de palabras por enunciado es de: 42.57 para el discurso: 1825-Adams.txt
# La relación de palabras por enunciado es de: 48.32 para el discurso: 1829-Jackson.txt
# La relación de palabras por enunciado es de: 42.23 para el discurso: 1833-Jackson.txt
# La relación de palabras por enunciado es de: 43.91 para el discurso: 1837-VanBuren.txt
# La relación de palabras por enunciado es de: 43.64 para el discurso: 1841-Harrison.txt
# La relación de palabras por enunciado es de: 33.96 para el discurso: 1845-Polk.txt
# La relación de palabras por enunciado es de: 53.73 para el discurso: 1849-Taylor.txt
# La relación de palabras por enunciado es de: 35.16 para el discurso: 1853-Pierce.txt
# La relación de palabras por enunciado es de: 34.81 para el discurso: 1857-Buchanan.txt
# La relación de palabras por enunciado es de: 29.02 para el discurso: 1861-Lincoln.txt
# La relación de palabras por enunciado es de: 29.07 para el discurso: 1865-Lincoln.txt
# La relación de palabras por enunciado es de: 30.22 para el discurso: 1869-Grant.txt
# La relación de palabras por enunciado es de: 33.59 para el discurso: 1873-Grant.txt
# La relación de palabras por enunciado es de: 46.17 para el discurso: 1877-Hayes.txt
# La relación de palabras por enunciado es de: 28.92 para el discurso: 1881-Garfield.txt
# La relación de palabras por enunciado es de: 41.55 para el discurso: 1885-Cleveland.txt
# La relación de palabras por enunciado es de: 30.25 para el discurso: 1889-Harrison.txt
# La relación de palabras por enunciado es de: 37.12 para el discurso: 1893-Cleveland.txt
# La relación de palabras por enunciado es de: 33.62 para el discurso: 1897-McKinley.txt
# La relación de palabras por enunciado es de: 24.50 para el discurso: 1901-McKinley.txt
# La relación de palabras por enunciado es de: 33.06 para el discurso: 1905-Roosevelt.txt
# La relación de palabras por enunciado es de: 36.77 para el discurso: 1909-Taft.txt
# La relación de palabras por enunciado es de: 28.01 para el discurso: 1913-Wilson.txt
# La relación de palabras por enunciado es de: 27.60 para el discurso: 1917-Wilson.txt
# La relación de palabras por enunciado es de: 25.21 para el discurso: 1921-Harding.txt
# La relación de palabras por enunciado es de: 22.55 para el discurso: 1925-Coolidge.txt
# La relación de palabras por enunciado es de: 24.62 para el discurso: 1929-Hoover.txt
# La relación de palabras por enunciado es de: 24.27 para el discurso: 1933-Roosevelt.txt
# La relación de palabras por enunciado es de: 21.03 para el discurso: 1937-Roosevelt.txt
# La relación de palabras por enunciado es de: 22.59 para el discurso: 1941-Roosevelt.txt
# La relación de palabras por enunciado es de: 24.50 para el discurso: 1945-Roosevelt.txt
# La relación de palabras por enunciado es de: 21.79 para el discurso: 1949-Truman.txt
# La relación de palabras por enunciado es de: 22.56 para el discurso: 1953-Eisenhower.txt
# La relación de palabras por enunciado es de: 20.84 para el discurso: 1957-Eisenhower.txt
# La relación de palabras por enunciado es de: 29.73 para el discurso: 1961-Kennedy.txt
# La relación de palabras por enunciado es de: 18.24 para el discurso: 1965-Johnson.txt
# La relación de palabras por enunciado es de: 22.88 para el discurso: 1969-Nixon.txt
# La relación de palabras por enunciado es de: 29.39 para el discurso: 1973-Nixon.txt
# La relación de palabras por enunciado es de: 26.04 para el discurso: 1977-Carter.txt
# La relación de palabras por enunciado es de: 22.06 para el discurso: 1981-Reagan.txt
# La relación de palabras por enunciado es de: 23.38 para el discurso: 1985-Reagan.txt
# La relación de palabras por enunciado es de: 18.71 para el discurso: 1989-Bush.txt
# La relación de palabras por enunciado es de: 22.90 para el discurso: 1993-Clinton.txt
# La relación de palabras por enunciado es de: 21.98 para el discurso: 1997-Clinton.txt
# La relación de palabras por enunciado es de: 18.81 para el discurso: 2001-Bush.txt
# La relación de palabras por enunciado es de: 25.01 para el discurso: 2005-Bush.txt
# La relación de palabras por enunciado es de: 24.34 para el discurso: 2009-Obama.txt
# La relación de palabras por enunciado es de: 25.75 para el discurso: 2013-Obama.txt
# La relación de palabras por enunciado es de: 18.81 para el discurso: 2017-Trump.txt

# %% [markdown]
# Emplearemos la librería **Pandas** para crear un **DataFrame** que contenga la información mostrada previamente, así como un **Indice**.
#
# ***Nota:*** El término *PPE* en el **DataFrame** se refiere a *Palabras Por Enunciado*.

# %%
#Importación de la librería Pandas
import pandas as pd

#Creación del DataFrame
datos_df = pd.DataFrame([int(discurso[:4]), len(nltk.corpus.inaugural.words(discurso))/len(nltk.corpus.inaugural.sents(discurso))] for discurso in nltk.corpus.inaugural.fileids())

#Nombre a las Columnas del DataFrame
datos_df.columns = ['Año', 'Promedio PPE']

#Impresión de los Resultados
print("La cantidad de entradas en el DataFrame son:", datos_df.shape[0], "renglones.")

#Mostrar el DataFrame
display(datos_df)
# Out:
# La cantidad de entradas en el DataFrame son: 58 renglones.
#      Año  Promedio PPE
# 0   1789     64.083333
# 1   1793     36.750000
# 2   1797     69.864865
# 3   1801     46.071429
# 4   1805     52.977778
# 5   1809     60.238095
# 6   1813     39.515152
# 7   1817     30.270492
# 8   1821     38.054264
# 9   1825     42.567568
# 10  1829     48.320000
# 11  1833     42.233333
# 12  1837     43.905263
# 13  1841     43.642857
# 14  1845     33.960784
# 15  1849     53.727273
# 16  1853     35.163462
# 17  1857     34.808989
# 18  1861     29.021739
# 19  1865     29.074074
# 20  1869     30.219512
# 21  1873     33.590909
# 22  1877     46.169492
# 23  1881     28.919643
# 24  1885     41.545455
# 25  1889     30.254777
# 26  1893     37.120690
# 27  1897     33.623077
# 28  1901     24.500000
# 29  1905     33.060606
# 30  1909     36.767296
# 31  1913     28.014706
# 32  1917     27.600000
# 33  1921     25.208054
# 34  1925     22.548223
# 35  1929     24.620253
# 36  1933     24.270588
# 37  1937     21.031250
# 38  1941     22.588235
# 39  1945     24.500000
# 40  1949     21.793103
# 41  1953     22.560976
# 42  1957     20.836957
# 43  1961     29.730769
# 44  1965     18.244681
# 45  1969     22.877358
# 46  1973     29.391304
# 47  1977     26.037736
# 48  1981     22.055118
# 49  1985     23.380952
# 50  1989     18.710345
# 51  1993     22.901235
# 52  1997     21.982143
# 53  2001     18.814433
# 54  2005     25.010526
# 55  2009     24.339286
# 56  2013     25.750000
# 57  2017     18.811111

# %% [markdown]
# Finalmente, empleando la librería **Matplotlib** se realizará la gráfica de los valores del **DataFrame**:

# %%
#Importación de la librería matplotlib
import matplotlib.pyplot as plt

#Definición de los parámetros de los gráficos
plt.rcParams.update({'font.size': 11, 'figure.figsize': (10, 8)}) 

#Gráfico del DataFrame
datos_df.plot("Año");
plt.title("Relación de Palabras por Enunciado");
plt.xlabel("Año del Discurso");
plt.ylabel("Relación");

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>.: Fin del Subtema :.</b>
# </div>
#
# ***Liga de aceso al siguiente Subtema:***
# <br>[c. Distribuciones de Frecuencia](c.%20Distribuciones%20de%20Frecuencia.ipynb)
