# %% [markdown]
# <div class="alert alert-block alert-info">
# <img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO">
# <br><font face = "Times New Roman" size = "6"><b><center>Maestría en Sistemas Computacionales</center></b></font>
# <br><font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
#
# <b><br><font face = "Times New Roman" size = "4"><center>Unidad 5: Proceso de Selección de Métodos</center></font>
# <font face = "Times New Roman" size = "4"><center>Tema 5.2: Redes Neuronales</center></font>
# <font face = "Times New Roman" size = "4"><center>Subtema g: Clasificación de Imágenes</center></font></b>
# </div>

# %% [markdown]
# ## CLASIFICACIÓN DE IMÁGENES
#
# ### Descripción del DataSet
#
# **Asirra (Animal Species Image Recognition for Restricting Access)** es un ***Host Integration Server (HIP)*** de **Microsoft** que funciona por medio de consultas a usuarios para identificar fotografías de perros y gatos. Esta tarea suele ser sumamente compleja para un equipo de cómputo, pero estudios han revelado que las personas pueden realizar esta tarea de manera más rápida y precisa.
#
# **Asirra** es único ya que tiene convenios con grandes compañías que hacen su uso, por ejemplo, con [PetFinder](https://www.petfinder.com), el cual es el sitio más grande a nivel mundial enfocado a encontrar hogares para animales. Ellos han proporcionado a **Microsoft** más de tres millones de imágenes de perros y gatos clasificadas totalmente pero de manera manual, esta información se ha recolectado de miles de refugios de animales a lo largo de los Estados Unidos.
# <br>
# <img src="./Imagenes/Kaggle_logo.png" style="width:240px;height:86px;" class="center">
# <br>
# Afortunadamente, existe un subgrupo de esa vasta base de datos, la cual está disponible a través de Kaggle [en esta liga](https://www.kaggle.com/c/dogs-vs-cats/data) llamada *Dogs vs. Cats*, con el objetivo de aplicarlo a procesos de investigación y desarrollo.
#
# El DataSet de 812MB contiene 25,000 imágenes de perros y gatos con sus respectivas clasificaciones, esto para realizar el entrenamiento de una red. Adicionalmente contiene 15,000 imágenes para la etapa de prueba.
#
# En el caso de este ejercicio, se han tomado solamente 1,000 imágenes (500 de perros y 500 de gatos) para hacer un DataSet más pequeño y sencillo de entrenar, adicionalmente se cuenta con 101 imágenes de prueba.
#
# **El problema consiste en entrenar una red neuronal en base a datos ya clasificados, para con ello poder prederir el tipo de animal (perro o gato) presente en una imagen. Por lo mismo, se enfoca a solo 2 clases.**
#
# Comenzaremos mostrando de manera aleatoria una imagen de cada tipo, contenidas dentro de los datos de *entrenamiento (train)*. Para ello se empleará la librería **SciKit-Image** (***skimage***) que ya se había empleado en sesiones previas del curso.

# %%
#Importación de librerías
import matplotlib.pyplot as plt
import random
from skimage import io                  

#Definición de los parámetros de los gráficos
plt.rcParams.update({'font.size': 11, 'figure.figsize': (10, 8)}) 

#Cargar y mostrar una imagen aleatoria de un perro desde el DataSet de Entrenamiento
dog_img = io.imread("./Data_DogCat/train/dog.{}.jpg".format(random.randint(0,499)))
plt.imshow(dog_img, origin=None)      
plt.axis('off')
plt.title("Imagen de un Perro del DataSet de Entrenamiento")
plt.show()
print("Dimensiones de la imagen:", dog_img.shape) 

#Cargar y mostrar una imagen aleatoria de un gato desde el DataSet de Entrenamiento
cat_img = io.imread("./Data_DogCat/train/cat.{}.jpg".format(random.randint(0,499)))
plt.imshow(cat_img, origin=None)        
plt.axis('off')
plt.title("Imagen de un Gato del DataSet de Entrenamiento")
plt.show()
print("Dimensiones de la imagen:", cat_img.shape)
# Out:
# Dimensiones de la imagen: (364, 450, 3)
# Dimensiones de la imagen: (375, 499, 3)

# %% [markdown]
# Se tendrán dos categorías de clasificación (*etiquetas o labels*), las cuales son `dog` y `cat`.
#
# Se comenzará preparando un **DataFrame** de **Pandas**, con el objetivo de recolectar las etiquetas de todos los archivos de entrenamiento (500 imágenes para cada etiqueta). El **DataFrame** tendrá los elementos:
#
# * `filename`: Nombre del archivo.
# * `category`: Categoría a la que pertenece el archivo, ya sea `dog` o `cat`.

# %%
#Importación de librerías
import pandas as pd
import os

#Creación del DataFrame
filenames = os.listdir('./Data_DogCat/train')
categories = []

#Asignación de los nombres y categorías desde los archivos de entrenamiento
for filename in filenames:
  category = filename.split('.')[0]
  if category == 'dog':
    categories.append('dog')
  else:
    categories.append('cat')

#Asignación al DataFrame
dog_cat_df = pd.DataFrame({'filename': filenames,'category': categories})
dog_cat_df.head(10)
# Out:
#       filename category
# 0    cat.6.jpg      cat
# 1  dog.211.jpg      dog
# 2  dog.205.jpg      dog
# 3  dog.239.jpg      dog
# 4  cat.239.jpg      cat
# 5  cat.211.jpg      cat
# 6  cat.205.jpg      cat
# 7  dog.365.jpg      dog
# 8  dog.403.jpg      dog
# 9  dog.417.jpg      dog

# %% [markdown]
# A continuación se realizarán algunas operaciones de preparación de los datos. Para ello se empleará la librería **SciKit-Learn**, la cual contiene herramientas simples y eficientes para análisis predictivo de datos.
# <br>
# <img src="./Imagenes/scikit.png" style="width:200px;height:108px;" class="center">
# <br>
# La documentación de **SciKit-Learn** se puede encontrar a través [de esta liga](https://scikit-learn.org/stable/).
#
# Los pasos a seguir son:
# 1. Extracción de **DataFrames** de entrenamiento y prueba de manera aleatoria empleando el método `train_test_split()` aplicado al **DataFrame** original.

# %%
#Importación de librerías
from sklearn.model_selection import train_test_split

#Extracción de DataFrames de entrenamiento y prueba
train_df, test_df = train_test_split(dog_cat_df, test_size = 0.2)

#Revisión de los tamaños de los DataFrames
print("\nEl tamaño del DataFrame de entrada es:", dog_cat_df.shape)
print("El tamaño del DataFrame para entrenamiento es:", train_df.shape)
print("El tamaño del DataFrame para prueba es:", test_df.shape)
# Out:
# El tamaño del DataFrame de entrada es: (1000, 2)
# El tamaño del DataFrame para entrenamiento es: (800, 2)
# El tamaño del DataFrame para prueba es: (200, 2)

# %% [markdown]
# Ahora se realiza un preprocesamiento de las imágenes a través de la función `ImageDataGenerator` de **Keras**. Para ello se empleará el método `.flow_from_dataframe()`, el cual permite tomar un **DataFrame** que contiene los nombres de los archivos y sus respectivas categorías de clasificación, y directamente lee las imágenes desde la ubicación especificada y mapeadas con la respectiva categoría.
#
# Para ello, primero se realiza una normalización de las imágenes (proceso normal para ajustar los valores de 0-255 a la escala de 0-1), y posteriormente se aplica el método `.flow_from_dataframe()` para generar los datos de las imágenes para el entrenamiento y para las pruebas de manera independiente:
#
# 1. Se indica el **DataFrame** desde donde se leen los datos.
# 2. Se indica el directorio desde donde se leeran las imágenes.
# 3. Se indica la columna del **DataFrame** que contiene los nombres de archivos con `x_col`.
# 4. Se indica la columna del **DataFrame** que contiene las categorías de cada archivo con `y_col`.
# 5. Se indica el tamaño al que se van a ajustar todas las imágenes con `target_size`.
# 6. Se especifica que las imágenes son arreglos 2-dimensionales de **NumPy** con `class_mode='categorical'`.
# 7. Se especifica el número de lotes (*batch*) a emplear por medio de `batch_size`.
#
# Se puede consultar más información sobre el método `.flow_from_dataframe()` de **Keras** [en esta liga](https://keras.io/preprocessing/image/).

# %%
#Importación de librerías
from keras.preprocessing.image import ImageDataGenerator

#Normalización de las Imágenes
datagen = ImageDataGenerator(rescale=1.0/255.0)

#Generador de Imágenes de Entrenamiento
traingenerator = datagen.flow_from_dataframe(train_df , './Data_DogCat/train', 
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (224,224),
                                             class_mode='categorical', 
                                             batch_size = 32)

#Generador de Imágenes de Prueba
testgenerator = datagen.flow_from_dataframe( test_df , './Data_DogCat/train',
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (224,224),
                                             class_mode='categorical', 
                                             batch_size = 32)
# Out:
# Found 800 validated image filenames belonging to 2 classes.
# Found 200 validated image filenames belonging to 2 classes.

# %% [markdown]
# Se prepara una **Red Neuronal** basada en el modelo secuencial (`Sequential`) de **Keras** a través de la librería **TensorFlow**, el cual consiste en una apilación (*stack*) lineal de capas (*layers*), esto es, se puede crear un modelo secuencial pasando la lista de capas a través del método `.add()`. Como características:
#
# 1. Se emplearán capas del tipo `Conv2D`, `MaxPooling2D`, `Flatten`, `Dense`, `BatchNormalization` y `Dropout`.
# 2. Se emplearán funciones de activación del tipo `relu` y `softmax`.
#
# Las capas (*layers*) de **Keras** disponibles a través de la librería **TensorFlow** se pueden consultar [en esta liga](https://www.tensorflow.org/api_docs/python/tf/keras/layers).
#
# Las funciones de activación disponibles en **TensorFlow** se pueden consultar [en esta liga](https://www.tensorflow.org/api_docs/python/tf/keras/activations).

# %%
#Importación de la Librería TensorFlow
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

#Preparación del Modelo
model = tf.keras.Sequential()

model.add(Conv2D(32, (5,5), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) #Son 2 debido a que son solo dos clases (perro o gato)

#Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Se puede visualizar una representación del modelo de la **Red Neuronal** creada con **TensorFlow**. Para ello se emplea el método `.summary()` aplicado al modelo. Esto es:

# %%
#Visualización de la Red Neuronal
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 106, 106, 64)      51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 49, 49, 128)       204928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 256)       819456
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 256)         1638656
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,899,970
# Trainable params: 3,898,946
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# Ahora se realiza el entrenamiento por un cierto número de épocas (*epochs*), las cuales son las iteraciones que se realizan. Para ello se emplea el método `.fit()` de **Keras**. Para ello:
#
# * Se proporcionan los datos de entrada de entrenamiento (*traingenerator*).
# * Se define la cantidad de épocas a emplear (`epochs`).
# * Se define la información que se usará para validar a través de `validation_data`.
# * Se define la cantidad de pasos a realizar con `validation_data` a través de `validation_steps`.
# * Se define la cantidad de pasos de cada época por medio de `steps_per_epoch`.
#
# La descripción detallada del método `.fit()` se puede consultar [en esta liga](https://keras.io/models/sequential/).
#
# ***Nota:*** El entrenamiento por época puede llevar alrededor de 100 segundos.

# %%
#Entrenamiento del modelo para 200 épocas
history = model.fit(
    traingenerator, 
    epochs = 200,
    validation_data = testgenerator,
    validation_steps= len(testgenerator),
    steps_per_epoch = len(traingenerator))
# Out:
# Epoch 1/200
# 25/25 [==============================] - 116s 5s/step - loss: 0.8717 - accuracy: 0.5150 - val_loss: 1.3639 - val_accuracy: 0.5100
# Epoch 2/200
# 25/25 [==============================] - 109s 4s/step - loss: 0.8127 - accuracy: 0.5312 - val_loss: 2.9949 - val_accuracy: 0.5100
# Epoch 3/200
# 25/25 [==============================] - 105s 4s/step - loss: 0.7887 - accuracy: 0.5450 - val_loss: 11.0024 - val_accuracy: 0.5100
# Epoch 4/200
# 25/25 [==============================] - 114s 5s/step - loss: 0.8092 - accuracy: 0.5312 - val_loss: 2.6305 - val_accuracy: 0.5100
# Epoch 5/200
# 25/25 [==============================] - 106s 4s/step - loss: 0.7357 - accuracy: 0.5713 - val_loss: 0.7276 - val_accuracy: 0.5600
# Epoch 6/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.7236 - accuracy: 0.6000 - val_loss: 0.7584 - val_accuracy: 0.5650
# Epoch 7/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.7206 - accuracy: 0.5863 - val_loss: 0.9171 - val_accuracy: 0.5150
# Epoch 8/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.7025 - accuracy: 0.6012 - val_loss: 0.6467 - val_accuracy: 0.6400
# Epoch 9/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6752 - accuracy: 0.6225 - val_loss: 0.7318 - val_accuracy: 0.5600
# Epoch 10/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6797 - accuracy: 0.6137 - val_loss: 0.8808 - val_accuracy: 0.5450
# Epoch 11/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6638 - accuracy: 0.6450 - val_loss: 0.9894 - val_accuracy: 0.5200
# Epoch 12/200
# 25/25 [==============================] - 109s 4s/step - loss: 0.6698 - accuracy: 0.6212 - val_loss: 0.6670 - val_accuracy: 0.5750
# Epoch 13/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.6713 - accuracy: 0.6300 - val_loss: 2.7398 - val_accuracy: 0.5100
# Epoch 14/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6880 - accuracy: 0.6037 - val_loss: 1.0076 - val_accuracy: 0.5800
# Epoch 15/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6663 - accuracy: 0.6112 - val_loss: 1.8467 - val_accuracy: 0.5100
# Epoch 16/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.6257 - accuracy: 0.6600 - val_loss: 0.7020 - val_accuracy: 0.6200
# Epoch 17/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.6219 - accuracy: 0.6787 - val_loss: 1.4140 - val_accuracy: 0.5100
# Epoch 18/200
# 25/25 [==============================] - 107s 4s/step - loss: 0.6025 - accuracy: 0.6825 - val_loss: 0.7248 - val_accuracy: 0.5650
# Epoch 19/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.5632 - accuracy: 0.7050 - val_loss: 0.6332 - val_accuracy: 0.6550
# Epoch 20/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.5574 - accuracy: 0.7088 - val_loss: 1.0232 - val_accuracy: 0.5150
# Epoch 21/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.5571 - accuracy: 0.7188 - val_loss: 0.6683 - val_accuracy: 0.5750
# Epoch 22/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.5196 - accuracy: 0.7400 - val_loss: 0.9969 - val_accuracy: 0.5550
# Epoch 23/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.4885 - accuracy: 0.7812 - val_loss: 0.6997 - val_accuracy: 0.6300
# Epoch 24/200
# 25/25 [==============================] - 104s 4s/step - loss: 0.4912 - accuracy: 0.7663 - val_loss: 0.7989 - val_accuracy: 0.6100
# Epoch 25/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.4677 - accuracy: 0.7688 - val_loss: 0.6694 - val_accuracy: 0.6850
# Epoch 26/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.4498 - accuracy: 0.7850 - val_loss: 0.6810 - val_accuracy: 0.6650
# Epoch 27/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.3774 - accuracy: 0.8288 - val_loss: 1.8798 - val_accuracy: 0.5000
# Epoch 28/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.3330 - accuracy: 0.8625 - val_loss: 1.3667 - val_accuracy: 0.5150
# Epoch 29/200
# 25/25 [==============================] - 107s 4s/step - loss: 0.2894 - accuracy: 0.8825 - val_loss: 1.1774 - val_accuracy: 0.5750
# Epoch 30/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.2341 - accuracy: 0.9125 - val_loss: 2.0792 - val_accuracy: 0.4900
# Epoch 31/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.1955 - accuracy: 0.9275 - val_loss: 2.7410 - val_accuracy: 0.4950
# Epoch 32/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.1378 - accuracy: 0.9500 - val_loss: 4.7354 - val_accuracy: 0.4900
# Epoch 33/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0960 - accuracy: 0.9725 - val_loss: 2.7854 - val_accuracy: 0.5450
# Epoch 34/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0806 - accuracy: 0.9775 - val_loss: 1.1894 - val_accuracy: 0.6300
# Epoch 35/200
# 25/25 [==============================] - 106s 4s/step - loss: 0.0704 - accuracy: 0.9812 - val_loss: 2.3855 - val_accuracy: 0.5400
# Epoch 36/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0903 - accuracy: 0.9650 - val_loss: 1.1023 - val_accuracy: 0.6600
# Epoch 37/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0614 - accuracy: 0.9750 - val_loss: 1.5758 - val_accuracy: 0.5900
# Epoch 38/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.0921 - accuracy: 0.9663 - val_loss: 1.3335 - val_accuracy: 0.6800
# Epoch 39/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.0747 - accuracy: 0.9725 - val_loss: 1.1316 - val_accuracy: 0.6500
# Epoch 40/200
# 25/25 [==============================] - 106s 4s/step - loss: 0.0365 - accuracy: 0.9887 - val_loss: 2.2400 - val_accuracy: 0.6500
# Epoch 41/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.3952 - val_accuracy: 0.6800
# Epoch 42/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.0780 - val_accuracy: 0.7100
# Epoch 43/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.2956 - val_accuracy: 0.7150
# Epoch 44/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.4330 - val_accuracy: 0.7000
# Epoch 45/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.2757 - val_accuracy: 0.7050
# Epoch 46/200
# 25/25 [==============================] - 108s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2723 - val_accuracy: 0.7350
# Epoch 47/200
# 25/25 [==============================] - 106s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3317 - val_accuracy: 0.7100
# Epoch 48/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2205 - val_accuracy: 0.7300
# Epoch 49/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2594 - val_accuracy: 0.7300
# Epoch 50/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 1.4622 - val_accuracy: 0.7050
# Epoch 51/200
# 25/25 [==============================] - 117s 5s/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 1.7178 - val_accuracy: 0.6600
# Epoch 52/200
# 25/25 [==============================] - 118s 5s/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 3.6882 - val_accuracy: 0.5650
# Epoch 53/200
# 25/25 [==============================] - 108s 4s/step - loss: 0.0317 - accuracy: 0.9862 - val_loss: 1.3312 - val_accuracy: 0.6600
# Epoch 54/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0567 - accuracy: 0.9737 - val_loss: 2.0003 - val_accuracy: 0.6750
# Epoch 55/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.0712 - accuracy: 0.9700 - val_loss: 1.5912 - val_accuracy: 0.6500
# Epoch 56/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0314 - accuracy: 0.9912 - val_loss: 1.4862 - val_accuracy: 0.7050
# Epoch 57/200
# 25/25 [==============================] - 102s 4s/step - loss: 0.0470 - accuracy: 0.9862 - val_loss: 3.4615 - val_accuracy: 0.5700
# Epoch 58/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0457 - accuracy: 0.9875 - val_loss: 1.6995 - val_accuracy: 0.6750
# Epoch 59/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0350 - accuracy: 0.9912 - val_loss: 1.6332 - val_accuracy: 0.6650
# Epoch 60/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0177 - accuracy: 0.9987 - val_loss: 1.5188 - val_accuracy: 0.6900
# Epoch 61/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0306 - accuracy: 0.9875 - val_loss: 1.4454 - val_accuracy: 0.6700
# Epoch 62/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 1.3829 - val_accuracy: 0.6850
# Epoch 63/200
# 25/25 [==============================] - 104s 4s/step - loss: 0.0406 - accuracy: 0.9887 - val_loss: 1.3073 - val_accuracy: 0.6600
# Epoch 64/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 1.4847 - val_accuracy: 0.6750
# Epoch 65/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 1.3857 - val_accuracy: 0.6850
# Epoch 66/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 1.6327 - val_accuracy: 0.6550
# Epoch 67/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 2.1918 - val_accuracy: 0.6250
# Epoch 68/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 1.5037 - val_accuracy: 0.6850
# Epoch 69/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.3077 - val_accuracy: 0.6850
# Epoch 70/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.7057 - val_accuracy: 0.6650
# Epoch 71/200
# 25/25 [==============================] - 95s 4s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.4074 - val_accuracy: 0.6850
# Epoch 72/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4787 - val_accuracy: 0.6700
# Epoch 73/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4594 - val_accuracy: 0.6800
# Epoch 74/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4835 - val_accuracy: 0.6700
# Epoch 75/200
# 25/25 [==============================] - 98s 4s/step - loss: 4.3451e-04 - accuracy: 1.0000 - val_loss: 1.5144 - val_accuracy: 0.6700
# Epoch 76/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4687 - val_accuracy: 0.6700
# Epoch 77/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4981 - val_accuracy: 0.6800
# Epoch 78/200
# 25/25 [==============================] - 98s 4s/step - loss: 7.1474e-04 - accuracy: 1.0000 - val_loss: 1.5727 - val_accuracy: 0.6800
# Epoch 79/200
# 25/25 [==============================] - 98s 4s/step - loss: 3.7442e-04 - accuracy: 1.0000 - val_loss: 1.5512 - val_accuracy: 0.6900
# Epoch 80/200
# 25/25 [==============================] - 98s 4s/step - loss: 3.6145e-04 - accuracy: 1.0000 - val_loss: 1.5412 - val_accuracy: 0.6900
# Epoch 81/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.5177 - val_accuracy: 0.6850
# Epoch 82/200
# 25/25 [==============================] - 98s 4s/step - loss: 8.0198e-04 - accuracy: 1.0000 - val_loss: 1.4578 - val_accuracy: 0.6850
# Epoch 83/200
# 25/25 [==============================] - 96s 4s/step - loss: 5.7597e-04 - accuracy: 1.0000 - val_loss: 1.5350 - val_accuracy: 0.6750
# Epoch 84/200
# 25/25 [==============================] - 95s 4s/step - loss: 6.9181e-04 - accuracy: 1.0000 - val_loss: 1.5606 - val_accuracy: 0.6800
# Epoch 85/200
# 25/25 [==============================] - 96s 4s/step - loss: 4.2904e-04 - accuracy: 1.0000 - val_loss: 1.5115 - val_accuracy: 0.6850
# Epoch 86/200
# 25/25 [==============================] - 100s 4s/step - loss: 2.3867e-04 - accuracy: 1.0000 - val_loss: 1.5139 - val_accuracy: 0.6850
# Epoch 87/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5701 - val_accuracy: 0.6950
# Epoch 88/200
# 25/25 [==============================] - 95s 4s/step - loss: 9.3885e-04 - accuracy: 1.0000 - val_loss: 1.6861 - val_accuracy: 0.6550
# Epoch 89/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.6150 - val_accuracy: 0.6750
# Epoch 90/200
# 25/25 [==============================] - 98s 4s/step - loss: 2.7419e-04 - accuracy: 1.0000 - val_loss: 1.6685 - val_accuracy: 0.6900
# Epoch 91/200
# 25/25 [==============================] - 98s 4s/step - loss: 3.3529e-04 - accuracy: 1.0000 - val_loss: 1.7235 - val_accuracy: 0.6900
# Epoch 92/200
# 25/25 [==============================] - 100s 4s/step - loss: 7.0739e-04 - accuracy: 1.0000 - val_loss: 1.6086 - val_accuracy: 0.6900
# Epoch 93/200
# 25/25 [==============================] - 96s 4s/step - loss: 2.8762e-04 - accuracy: 1.0000 - val_loss: 1.5357 - val_accuracy: 0.6900
# Epoch 94/200
# 25/25 [==============================] - 97s 4s/step - loss: 4.0146e-04 - accuracy: 1.0000 - val_loss: 1.5579 - val_accuracy: 0.7000
# Epoch 95/200
# 25/25 [==============================] - 95s 4s/step - loss: 1.8851e-04 - accuracy: 1.0000 - val_loss: 1.5627 - val_accuracy: 0.6750
# Epoch 96/200
# 25/25 [==============================] - 98s 4s/step - loss: 2.5167e-04 - accuracy: 1.0000 - val_loss: 1.6467 - val_accuracy: 0.6950
# Epoch 97/200
# 25/25 [==============================] - 97s 4s/step - loss: 1.3064e-04 - accuracy: 1.0000 - val_loss: 1.6241 - val_accuracy: 0.6850
# Epoch 98/200
# 25/25 [==============================] - 102s 4s/step - loss: 1.5843e-04 - accuracy: 1.0000 - val_loss: 1.6283 - val_accuracy: 0.6850
# Epoch 99/200
# 25/25 [==============================] - 98s 4s/step - loss: 1.5794e-04 - accuracy: 1.0000 - val_loss: 1.5964 - val_accuracy: 0.6750
# Epoch 100/200
# 25/25 [==============================] - 95s 4s/step - loss: 5.3728e-04 - accuracy: 1.0000 - val_loss: 1.6072 - val_accuracy: 0.6800
# Epoch 101/200
# 25/25 [==============================] - 98s 4s/step - loss: 1.7780e-04 - accuracy: 1.0000 - val_loss: 1.5870 - val_accuracy: 0.6850
# Epoch 102/200
# 25/25 [==============================] - 98s 4s/step - loss: 2.1516e-04 - accuracy: 1.0000 - val_loss: 1.5764 - val_accuracy: 0.6900
# Epoch 103/200
# 25/25 [==============================] - 95s 4s/step - loss: 4.0119e-04 - accuracy: 1.0000 - val_loss: 1.5976 - val_accuracy: 0.6900
# Epoch 104/200
# 25/25 [==============================] - 102s 4s/step - loss: 1.9680e-04 - accuracy: 1.0000 - val_loss: 1.6362 - val_accuracy: 0.6850
# Epoch 105/200
# 25/25 [==============================] - 95s 4s/step - loss: 7.0052e-04 - accuracy: 1.0000 - val_loss: 1.7680 - val_accuracy: 0.6850
# Epoch 106/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.6114 - val_accuracy: 0.6850
# Epoch 107/200
# 25/25 [==============================] - 95s 4s/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 1.4995 - val_accuracy: 0.6750
# Epoch 108/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 3.9081 - val_accuracy: 0.6250
# Epoch 109/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.1023 - accuracy: 0.9663 - val_loss: 2.8839 - val_accuracy: 0.6300
# Epoch 110/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.0756 - accuracy: 0.9650 - val_loss: 1.8285 - val_accuracy: 0.6650
# Epoch 111/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0597 - accuracy: 0.9775 - val_loss: 2.0318 - val_accuracy: 0.6450
# Epoch 112/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0799 - accuracy: 0.9712 - val_loss: 2.8668 - val_accuracy: 0.6200
# Epoch 113/200
# 25/25 [==============================] - 95s 4s/step - loss: 0.0375 - accuracy: 0.9875 - val_loss: 1.8697 - val_accuracy: 0.6550
# Epoch 114/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0397 - accuracy: 0.9837 - val_loss: 2.0816 - val_accuracy: 0.6150
# Epoch 115/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 1.6896 - val_accuracy: 0.6650
# Epoch 116/200
# 25/25 [==============================] - 103s 4s/step - loss: 0.0433 - accuracy: 0.9812 - val_loss: 1.9947 - val_accuracy: 0.6750
# Epoch 117/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 1.5265 - val_accuracy: 0.6950
# Epoch 118/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 2.0126 - val_accuracy: 0.6550
# Epoch 119/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 1.6385 - val_accuracy: 0.6900
# Epoch 120/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 1.4539 - val_accuracy: 0.6800
# Epoch 121/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 1.3513 - val_accuracy: 0.6950
# Epoch 122/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 1.3833 - val_accuracy: 0.6750
# Epoch 123/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.4852 - val_accuracy: 0.6900
# Epoch 124/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5762 - val_accuracy: 0.7050
# Epoch 125/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5736 - val_accuracy: 0.7100
# Epoch 126/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 1.7154 - val_accuracy: 0.7000
# Epoch 127/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.7976 - val_accuracy: 0.6950
# Epoch 128/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.6689 - val_accuracy: 0.7000
# Epoch 129/200
# 25/25 [==============================] - 97s 4s/step - loss: 4.9045e-04 - accuracy: 1.0000 - val_loss: 1.6362 - val_accuracy: 0.7100
# Epoch 130/200
# 25/25 [==============================] - 94s 4s/step - loss: 6.0501e-04 - accuracy: 1.0000 - val_loss: 1.6047 - val_accuracy: 0.7000
# Epoch 131/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.8639 - val_accuracy: 0.6750
# Epoch 132/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.8933 - val_accuracy: 0.6500
# Epoch 133/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 1.5661 - val_accuracy: 0.7000
# Epoch 134/200
# 25/25 [==============================] - 101s 4s/step - loss: 6.4404e-04 - accuracy: 1.0000 - val_loss: 1.5668 - val_accuracy: 0.7100
# Epoch 135/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0026 - accuracy: 0.9987 - val_loss: 1.8107 - val_accuracy: 0.6950
# Epoch 136/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 2.8605 - val_accuracy: 0.6350
# Epoch 137/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 2.0566 - val_accuracy: 0.6350
# Epoch 138/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0348 - accuracy: 0.9900 - val_loss: 2.1266 - val_accuracy: 0.6950
# Epoch 139/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 2.3062 - val_accuracy: 0.6750
# Epoch 140/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.1197 - accuracy: 0.9550 - val_loss: 2.0622 - val_accuracy: 0.6300
# Epoch 141/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.1290 - accuracy: 0.9550 - val_loss: 5.0684 - val_accuracy: 0.5250
# Epoch 142/200
# 25/25 [==============================] - 96s 4s/step - loss: 0.0401 - accuracy: 0.9875 - val_loss: 1.9002 - val_accuracy: 0.6350
# Epoch 143/200
# 25/25 [==============================] - 95s 4s/step - loss: 0.0334 - accuracy: 0.9862 - val_loss: 2.0740 - val_accuracy: 0.6400
# Epoch 144/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0347 - accuracy: 0.9875 - val_loss: 1.4497 - val_accuracy: 0.6800
# Epoch 145/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 1.6999 - val_accuracy: 0.6250
# Epoch 146/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0152 - accuracy: 0.9987 - val_loss: 1.9889 - val_accuracy: 0.6200
# Epoch 147/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.6308 - val_accuracy: 0.6450
# Epoch 148/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0099 - accuracy: 0.9975 - val_loss: 1.5984 - val_accuracy: 0.7050
# Epoch 149/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 2.3832 - val_accuracy: 0.6100
# Epoch 150/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 2.8963 - val_accuracy: 0.5950
# Epoch 151/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 1.7843 - val_accuracy: 0.6750
# Epoch 152/200
# 25/25 [==============================] - 101s 4s/step - loss: 0.0050 - accuracy: 0.9975 - val_loss: 1.9413 - val_accuracy: 0.6700
# Epoch 153/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.7721 - val_accuracy: 0.6350
# Epoch 154/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.7345 - val_accuracy: 0.6550
# Epoch 155/200
# 25/25 [==============================] - 97s 4s/step - loss: 9.0193e-04 - accuracy: 1.0000 - val_loss: 1.7397 - val_accuracy: 0.6900
# Epoch 156/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.7305 - val_accuracy: 0.6850
# Epoch 157/200
# 25/25 [==============================] - 93s 4s/step - loss: 6.2465e-04 - accuracy: 1.0000 - val_loss: 1.7913 - val_accuracy: 0.6800
# Epoch 158/200
# 25/25 [==============================] - 101s 4s/step - loss: 4.4515e-04 - accuracy: 1.0000 - val_loss: 1.7732 - val_accuracy: 0.6800
# Epoch 159/200
# 25/25 [==============================] - 97s 4s/step - loss: 5.6714e-04 - accuracy: 1.0000 - val_loss: 1.7843 - val_accuracy: 0.6750
# Epoch 160/200
# 25/25 [==============================] - 97s 4s/step - loss: 7.4665e-04 - accuracy: 1.0000 - val_loss: 1.8129 - val_accuracy: 0.6750
# Epoch 161/200
# 25/25 [==============================] - 97s 4s/step - loss: 2.0505e-04 - accuracy: 1.0000 - val_loss: 1.8224 - val_accuracy: 0.6700
# Epoch 162/200
# 25/25 [==============================] - 94s 4s/step - loss: 2.9983e-04 - accuracy: 1.0000 - val_loss: 1.8218 - val_accuracy: 0.6700
# Epoch 163/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.8481 - val_accuracy: 0.6950
# Epoch 164/200
# 25/25 [==============================] - 100s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.5660 - val_accuracy: 0.6700
# Epoch 165/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 1.6456 - val_accuracy: 0.6700
# Epoch 166/200
# 25/25 [==============================] - 97s 4s/step - loss: 7.0568e-04 - accuracy: 1.0000 - val_loss: 1.6375 - val_accuracy: 0.6650
# Epoch 167/200
# 25/25 [==============================] - 94s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7782 - val_accuracy: 0.6550
# Epoch 168/200
# 25/25 [==============================] - 97s 4s/step - loss: 4.7472e-04 - accuracy: 1.0000 - val_loss: 1.8107 - val_accuracy: 0.6650
# Epoch 169/200
# 25/25 [==============================] - 98s 4s/step - loss: 2.0702e-04 - accuracy: 1.0000 - val_loss: 1.8412 - val_accuracy: 0.6500
# Epoch 170/200
# 25/25 [==============================] - 97s 4s/step - loss: 5.3159e-04 - accuracy: 1.0000 - val_loss: 1.8265 - val_accuracy: 0.6550
# Epoch 171/200
# 25/25 [==============================] - 93s 4s/step - loss: 4.3580e-04 - accuracy: 1.0000 - val_loss: 1.7988 - val_accuracy: 0.6700
# Epoch 172/200
# 25/25 [==============================] - 96s 4s/step - loss: 4.0349e-04 - accuracy: 1.0000 - val_loss: 1.8125 - val_accuracy: 0.6700
# Epoch 173/200
# 25/25 [==============================] - 97s 4s/step - loss: 2.8889e-04 - accuracy: 1.0000 - val_loss: 1.8318 - val_accuracy: 0.6700
# Epoch 174/200
# 25/25 [==============================] - 93s 4s/step - loss: 0.0024 - accuracy: 0.9987 - val_loss: 1.9319 - val_accuracy: 0.7000
# Epoch 175/200
# 25/25 [==============================] - 98s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.1838 - val_accuracy: 0.6600
# Epoch 176/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.8463 - val_accuracy: 0.6300
# Epoch 177/200
# 25/25 [==============================] - 97s 4s/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 2.4112 - val_accuracy: 0.6650
# Epoch 178/200
# 25/25 [==============================] - 97s 4s/step - loss: 8.2031e-04 - accuracy: 1.0000 - val_loss: 1.9709 - val_accuracy: 0.6550
# Epoch 179/200
# 25/25 [==============================] - 94s 4s/step - loss: 6.2112e-04 - accuracy: 1.0000 - val_loss: 1.8528 - val_accuracy: 0.6400
# Epoch 180/200
# 25/25 [==============================] - 97s 4s/step - loss: 6.8809e-04 - accuracy: 1.0000 - val_loss: 1.9262 - val_accuracy: 0.6450
# Epoch 181/200
# 25/25 [==============================] - 100s 4s/step - loss: 3.5111e-04 - accuracy: 1.0000 - val_loss: 1.9003 - val_accuracy: 0.6400
# Epoch 182/200
# 25/25 [==============================] - 99s 4s/step - loss: 6.6686e-04 - accuracy: 1.0000 - val_loss: 1.9512 - val_accuracy: 0.6450
# Epoch 183/200
# 25/25 [==============================] - 97s 4s/step - loss: 3.3296e-04 - accuracy: 1.0000 - val_loss: 1.8921 - val_accuracy: 0.6500
# Epoch 184/200
# 25/25 [==============================] - 94s 4s/step - loss: 1.4208e-04 - accuracy: 1.0000 - val_loss: 1.8611 - val_accuracy: 0.6450
# Epoch 185/200
# 25/25 [==============================] - 97s 4s/step - loss: 2.7793e-04 - accuracy: 1.0000 - val_loss: 1.8614 - val_accuracy: 0.6500
# Epoch 186/200
# 25/25 [==============================] - 97s 4s/step - loss: 1.1754e-04 - accuracy: 1.0000 - val_loss: 1.8700 - val_accuracy: 0.6500
# Epoch 187/200
# 25/25 [==============================] - 100s 4s/step - loss: 3.9926e-04 - accuracy: 1.0000 - val_loss: 1.8936 - val_accuracy: 0.6800
# Epoch 188/200
# 25/25 [==============================] - 98s 4s/step - loss: 1.8476e-04 - accuracy: 1.0000 - val_loss: 1.9161 - val_accuracy: 0.6750
# Epoch 189/200
# 25/25 [==============================] - 94s 4s/step - loss: 2.8680e-04 - accuracy: 1.0000 - val_loss: 1.8819 - val_accuracy: 0.6850
# Epoch 190/200
# 25/25 [==============================] - 97s 4s/step - loss: 5.5331e-05 - accuracy: 1.0000 - val_loss: 1.8641 - val_accuracy: 0.6750
# Epoch 191/200
# 25/25 [==============================] - 96s 4s/step - loss: 1.1164e-04 - accuracy: 1.0000 - val_loss: 1.8639 - val_accuracy: 0.6800
# Epoch 192/200
# 25/25 [==============================] - 96s 4s/step - loss: 9.3554e-04 - accuracy: 1.0000 - val_loss: 1.8765 - val_accuracy: 0.6550
# Epoch 193/200
# 25/25 [==============================] - 101s 4s/step - loss: 1.8098e-04 - accuracy: 1.0000 - val_loss: 1.8476 - val_accuracy: 0.6550
# Epoch 194/200
# 25/25 [==============================] - 93s 4s/step - loss: 1.0483e-04 - accuracy: 1.0000 - val_loss: 1.8335 - val_accuracy: 0.6600
# Epoch 195/200
# 25/25 [==============================] - 96s 4s/step - loss: 8.7116e-05 - accuracy: 1.0000 - val_loss: 1.8523 - val_accuracy: 0.6600
# Epoch 196/200
# 25/25 [==============================] - 96s 4s/step - loss: 2.3195e-04 - accuracy: 1.0000 - val_loss: 1.8540 - val_accuracy: 0.6600
# Epoch 197/200
# 25/25 [==============================] - 93s 4s/step - loss: 9.3175e-05 - accuracy: 1.0000 - val_loss: 1.8802 - val_accuracy: 0.6600
# Epoch 198/200
# 25/25 [==============================] - 96s 4s/step - loss: 1.0449e-04 - accuracy: 1.0000 - val_loss: 1.9094 - val_accuracy: 0.6650
# Epoch 199/200
# 25/25 [==============================] - 101s 4s/step - loss: 4.0942e-05 - accuracy: 1.0000 - val_loss: 1.9155 - val_accuracy: 0.6600
# Epoch 200/200
# 25/25 [==============================] - 93s 4s/step - loss: 1.2900e-04 - accuracy: 1.0000 - val_loss: 1.9293 - val_accuracy: 0.6750

# %% [markdown]
# Ahora se muestra el gráfico del nivel de asertividad (*accuracy*) a través de las épocas (*epoch*) de entenamiento, con lo cual se puede realizar una comparativa de su desempeño.
#
# La documentación de **Keras** recomienda emplear el código mostrado a continuación, el cual puede ser consultado [en esta liga](https://keras.io/visualization/#training-history-visualization).

# %%
#Resumen del entrenamiento por medio de la asertividad (accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Nivel de Certeza del Modelo')
plt.ylabel('Certeza')
plt.xlabel('Épocas')
plt.legend(['Entrenamiento', 'Prueba'], loc='upper left')
plt.show()

# %% [markdown]
# Ahora se muestra el gráfico del nivel de pérdida (*loss*) a través de las épocas (*epoch*) de entenamiento, con lo cual se puede realizar una comparativa de su desempeño.
#
# La documentación de **Keras** recomienda emplear el código mostrado a continuación, el cual puede ser consultado [en esta liga](https://keras.io/visualization/#training-history-visualization).

# %%
#Resumen del entrenamiento por medio de la pérdida (loss)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Nivel de Pérdida del Modelo')
plt.ylabel('Pérdida')
plt.xlabel('Épocas')
plt.legend(['Entrenamiento', 'Prueba'], loc='upper left')
plt.show()

# %% [markdown]
# Se generará un **Diccionario** en el cual se contengan las categorías clasificación de las imágenes (en este caso son solamente dos: `cat` y `dog`.

# %%
#Generar un Diccionario con las Categorías de Clasificación de las Imágenes
traingenerator.class_indices
labels = (traingenerator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print("Las categorías de clasificación de las imágenes son:", labels)
# Out:
# Las categorías de clasificación de las imágenes son: {0: 'cat', 1: 'dog'}

# %% [markdown]
# Ahora se define una función de **Python** la cual recibe el modelo entrenado y la ubicación de un archivo de prueba, y entrega la clasificación del contenido de la imágen.

# %%
#Importación de Librerías
import numpy as np
from skimage.transform import resize

#Definir una Función para Pruebas
def test_the_model(model, image_path):
  img = io.imread(image_path)
  
  plt.imshow(img, origin=None)
  plt.axis('off')
  plt.title("Imagen de Prueba")
    
  img = resize(img,(224,224))
  img = np.reshape(img,(1,224,224,3))
  img = img/255.0

  prediction = model.predict(img)
  prediction = np.argmax(prediction)
  
  labels = (traingenerator.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  
  return labels[prediction]

# %% [markdown]
# Para probar el modelo, llamamos a la función `test_the_model` con una imagen de prueba e imprimimos el resultado:

# %%
#Llamado a la Función test_the_model para probar el modelo
print('La categoría para la imagen de prueba es:', test_the_model(model, './Data_DogCat/test/10.jpg'))
# Out:
# La categoría para la imagen de prueba es: cat

# %% [markdown]
# Ahora, es posible guardar la historia del entrenamiento que se obtuvo con el método `model.fit_generator` en un archivo CSV, esto puede ser de utilidad para un análisis posterior de los datos:

# %%
#Guardar la Historia del Entrenamiento en formato CSV
history_df = pd.DataFrame(history.history) 
with open('./Data_DogCat/history/history.csv', mode='w') as f:
    history_df.to_csv(f)

# %% [markdown]
# De igual manera, es posible guardar el modelo a traves de la función `model.save`, la cual guarda la arquitectura del modelo, sus pesos, y la configuración de entrenamiento en un solo archivo. Esto permite exportar un modelo para que pueda ser usado sin acceso al código original. Debido a que el estado de optimización también es recuperado, puede continuarse un proceso de entrenamiento desde donde se dejó.
#
# El modelo completo puede ser guardado en distintos formatos (`SavedModel` y `HDF5`). Para **TensorFlow**, el formato `SavedModel` es el predeterminado a través de la extensión `TF2`. Sin embargo, el modelo puede ser guardado también en un formato `HDF5`.
#
# La descripción detallada de la función `model.save` se puede encontrar [en esta liga](https://www.tensorflow.org/tutorials/keras/save_and_load).

# %%
#Warnings OFF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

#Guardado del Modelo
model.save('./Data_DogCat/model')
# Out:
# WARNING:tensorflow:From /Users/Villalon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/Villalon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./Data_DogCat/model/assets

# %% [markdown]
# Ahora, se puede cargar ese modelo guardado como un nuevo modelo empleando el método `.load_model()` de **Keras** a través de la librería de **TensorFlow** de la siguiente manera:

# %%
#Cargar el Modelo
new_model = tf.keras.models.load_model('./Data_DogCat/model')

# %% [markdown]
# Para probarlo, volvemos a invocar la función `test_the_model` pero con el nuevo modelo que se ha cargado:

# %%
#Llamado a la Función test_the_model para probar el modelo
print('La categoría para la imagen de prueba es:', test_the_model(new_model, './Imagenes/Lily.jpg'))
# Out:
# La categoría para la imagen de prueba es: cat

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>.: Fin del Tema :.</b>
# </div>
